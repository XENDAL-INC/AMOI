# %%
# %matplotlib inline

import tensorflow as tf
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.applications.vgg16 import VGG16
from sklearn import preprocessing
import matplotlib.pyplot as plt
import numpy as np
import os
import pprint
pp = pprint.PrettyPrinter(indent=4)

# %%
import joblib
from skimage.io import imread
from skimage.transform import resize

gramPositive_labels=['Escherichia Coli(+ve)',
 'Fusobacterium(+ve)',
 'Pseudomonas Aeruginosa(+ve)']
gramNegative_labels=['Bifidobacterium spp(-ve)',
 'Candida Albicans(-ve)',
 'Enterococcus faecalis(-ve)',
 'Lactobacillus Gasseri(-ve)',
 'Listeria Monocytogenes(-ve)',
 'Staphylococcus Epidermidis(-ve)',
 'Streptococcus Agalactiae(-ve)']

all_labels=['Bifidobacterium spp(-ve)',
 'Candida Albicans(-ve)',
 'Enterococcus faecalis(-ve)',
 'Escherichia Coli(+ve)',
 'Fusobacterium(+ve)',
 'Lactobacillus Gasseri(-ve)',
 'Listeria Monocytogenes(-ve)',
 'Pseudomonas Aeruginosa(+ve)',
 'Staphylococcus Epidermidis(-ve)',
 'Streptococcus Agalactiae(-ve)']

labels = all_labels

labelsN = []
i=0
for label in labels:
    labelsN.append(int(i))
    i=i+1

def resize_all(src, pklname, include, width=2048, height=1532):
    """
    load images from path, resize them and write them as arrays to a dictionary, 
    together with labels and metadata. The dictionary is written to a pickle file 
    named '{pklname}_{width}x{height}px.pkl'.
     
    Parameter
    ---------
    src: str
        path to data
    pklname: str
        path to output file
    width: int
        target width of the image in pixels
    include: set[str]
        set containing str
    """
     
    height = height if height is not None else width
     
    data = dict()
    data['description'] = 'bacteria images'.format(int(width), int(height))
    data['label'] = []
    data['filename'] = []
    data['data'] = []
     
    pklname = f"{pklname}_{width}x{height}px.pkl"
    
    # read all images in PATH, resize and write to DESTINATION_PATH
    for subdir in os.listdir(src):
        if subdir in include:
            print(subdir)
            current_path = os.path.join(src, subdir)
 
            for file in os.listdir(current_path):
                if file[-3:] in {'jpg', 'png'}:
                    im = imread(os.path.join(current_path, file))
                    #im = resize(im, (width, height)) #[:,:,::-1]
                    data['label'].append(subdir)
                    data['filename'].append(file)
                    data['data'].append(im)
                    imH = np.fliplr(im)
                    imV = np.flipud(im)
                    #flipH
                    data['label'].append(subdir)
                    data['filename'].append("flipH_" + file)
                    data['data'].append(imH)
                    #flipV
                    data['label'].append(subdir)
                    data['filename'].append("flipV_" + file)
                    data['data'].append(imV)

 
        joblib.dump(data, pklname)

# %%
# modify to fit your system
data_path = 'D:/Xendal/University/Grad/Dataset'
os.listdir(data_path)
# Out:
# ['Bifidobacterium spp(-ve)',
#  'Candida Albicans(-ve)',
#  'Enterococcus faecalis(-ve)',
#  'Escherichia Coli(+ve)',
#  'Fusobacterium(+ve)',
#  'Lactobacillus Gasseri(-ve)',
#  'Listeria Monocytogenes(-ve)',
#  'Pseudomonas Aeruginosa(+ve)',
#  'Staphylococcus Epidermidis(-ve)',
#  'Streptococcus Agalactiae(-ve)']

# %%
base_name = 'D:/Xendal/University/Grad/datasetPickle/augmented_bacteria'
width = 2048
height = 1532

gramPositive_include={'Escherichia Coli(+ve)',
 'Fusobacterium(+ve)',
 'Pseudomonas Aeruginosa(+ve)'}

gramNegative_include={'Bifidobacterium spp(-ve)',
 'Candida Albicans(-ve)',
 'Enterococcus faecalis(-ve)',
 'Lactobacillus Gasseri(-ve)',
 'Listeria Monocytogenes(-ve)',
 'Staphylococcus Epidermidis(-ve)',
 'Streptococcus Agalactiae(-ve)'}

all_include={'Bifidobacterium spp(-ve)',
 'Candida Albicans(-ve)',
 'Enterococcus faecalis(-ve)',
 'Escherichia Coli(+ve)',
 'Fusobacterium(+ve)',
 'Lactobacillus Gasseri(-ve)',
 'Listeria Monocytogenes(-ve)',
 'Pseudomonas Aeruginosa(+ve)',
 'Staphylococcus Epidermidis(-ve)',
 'Streptococcus Agalactiae(-ve)'}

include = all_include
   
#resize_all(src=data_path, pklname=base_name, width=width, include=include,)

# %%
from collections import Counter
 
data = joblib.load(f'{base_name}_{width}x{height}px.pkl')
 
print('number of samples: ', len(data['data']))
print('keys: ', list(data.keys()))
print('description: ', data['description'])
print('image shape: ', data['data'][0].shape)
print('labels:', np.unique(data['label']))
 
Counter(data['label'])
# Out:
# number of samples:  624
# keys:  ['description', 'label', 'filename', 'data']
# description:  bacteria images
# image shape:  (1532, 2048, 3)
# labels: ['Bifidobacterium spp(-ve)' 'Candida Albicans(-ve)'
#  'Enterococcus faecalis(-ve)' 'Escherichia Coli(+ve)' 'Fusobacterium(+ve)'
#  'Lactobacillus Gasseri(-ve)' 'Listeria Monocytogenes(-ve)'
#  'Pseudomonas Aeruginosa(+ve)' 'Staphylococcus Epidermidis(-ve)'
#  'Streptococcus Agalactiae(-ve)']
# Counter({'Bifidobacterium spp(-ve)': 69,
#          'Candida Albicans(-ve)': 60,
#          'Enterococcus faecalis(-ve)': 60,
#          'Escherichia Coli(+ve)': 60,
#          'Fusobacterium(+ve)': 69,
#          'Lactobacillus Gasseri(-ve)': 60,
#          'Listeria Monocytogenes(-ve)': 66,
#          'Pseudomonas Aeruginosa(+ve)': 60,
#          'Staphylococcus Epidermidis(-ve)': 60,
#          'Streptococcus Agalactiae(-ve)': 60})

# %%
# use np.unique to get all unique values in the list of labels
labels = np.unique(data['label'])
 
# set up the matplotlib figure and axes, based on the number of labels
fig, axes = plt.subplots(1, len(labels))
fig.set_size_inches(15,4)
fig.tight_layout()
 
# make a plot for every label (equipment) type. The index method returns the 
# index of the first item corresponding to its search string, label in this case
for ax, label in zip(axes, labels):
    idx = data['label'].index(label)
     
    ax.imshow(data['data'][idx])
    ax.axis('off')
    ax.set_title(label)

# %%
X = np.array(data['data'])
y = np.array(data['label'])

# %%
le = preprocessing.LabelEncoder()
le.fit(y)
y_labels_encoded = le.transform(y)

# %%
from sklearn.model_selection import train_test_split
 
X_train, X_test, y_train, y_test = train_test_split(
    X, 
    y_labels_encoded, 
    test_size=0.2, 
    shuffle=True,
    random_state=42,
)

# %%
def plot_bar(y, loc='left', relative=True):
    width = 0.35
    if loc == 'left':
        n = -0.5
    elif loc == 'right':
        n = 0.5
     
    # calculate counts per type and sort, to ensure their order
    unique, counts = np.unique(y, return_counts=True)
    sorted_index = np.argsort(unique)
    unique = unique[sorted_index]
     
    if relative:
        # plot as a percentage
        counts = 100*counts[sorted_index]/len(y)
        ylabel_text = '% count'
    else:
        # plot counts
        counts = counts[sorted_index]
        ylabel_text = 'count'
         
    xtemp = np.arange(len(unique))
     
    plt.bar(xtemp + n*width, counts, align='center', alpha=.7, width=width)
    plt.xticks(xtemp, unique, rotation=45)
    plt.xlabel('equipment type')
    plt.ylabel(ylabel_text)
    
plt.suptitle('relative amount of photos per type')
plot_bar(y_train, loc='left')
plot_bar(y_test, loc='right')
plt.legend([
    'train ({0} photos)'.format(len(y_train)), 
    'test ({0} photos)'.format(len(y_test))
]);

# %%
from sklearn.base import BaseEstimator, TransformerMixin
from skimage import color
from skimage.feature import hog
from sklearn import svm
from sklearn.metrics import classification_report,accuracy_score

# %%
class ResizeTransformer(BaseEstimator, TransformerMixin):
    """
    Scales array to 1/3
    """
 
    def __init__(self):
        pass
 
    def fit(self, X, y=None):
        """returns itself"""
        return self
 
    def transform(self, X, y=None):
        """perform the transformation and return an array"""
        return np.array([resize(img, (img.shape[0] // 6.8, img.shape[1] // 6.8), anti_aliasing='True') for img in X])

# %%
from sklearn.linear_model import SGDClassifier
from sklearn.model_selection import cross_val_predict
from sklearn.preprocessing import StandardScaler, Normalizer
import skimage
import cv2 as cv
from skimage.transform import rescale

resizify = ResizeTransformer()

X_train_resize=resizify.fit_transform(X_train)

print(X_train.shape)
print(X_train_resize.shape)
# Out:
# (499, 1532, 2048, 3)
# (499, 225, 301, 3)

# %%
X_test_resize=resizify.fit_transform(X_test)

print(X_test.shape)
print(X_test_resize.shape)
# Out:
# (125, 1532, 2048, 3)
# (125, 225, 301, 3)

# %%
tf.keras.backend.clear_session()
VGG_model = VGG16(include_top=False, pooling='max', weights='imagenet') 

for layer in VGG_model.layers:
    layer.trainable = False

VGG_model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, None, None, 3)]   0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, None, None, 64)    1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, None, None, 64)    36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, None, None, 64)    0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, None, None, 128)   73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, None, None, 128)   147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, None, None, 128)   0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, None, None, 256)   295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, None, None, 256)   590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, None, None, 256)   590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, None, None, 256)   0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, None, None, 512)   1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, None, None, 512)   0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, None, None, 512)   0
# _________________________________________________________________
# global_max_pooling2d (Global (None, 512)               0
# =================================================================
# Total params: 14,714,688
# Trainable params: 0
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
#ann.summary()
feature_extractor=VGG_model.predict(X_train_resize)
X_train_feats = feature_extractor.reshape(feature_extractor.shape[0], -1)

print(X_train_feats.shape)
print(X_train_feats[:2])
# Out:
# (499, 512)
# [[0.41741243 0.         1.5818031  ... 0.29542446 1.1568608  0.        ]
#  [0.39948136 0.         0.44454506 ... 0.         1.0460341  0.        ]]

# %%
feature_extractor=VGG_model.predict(X_test_resize)
X_test_feats = feature_extractor.reshape(feature_extractor.shape[0], -1)

print(X_test_feats.shape)
print(X_test_feats[:2])
# Out:
# (125, 512)
# [[0.38227808 0.         0.28836006 ... 0.         1.2550147  0.        ]
#  [0.42466408 0.         0.23382491 ... 0.02088668 1.2557722  0.        ]]

# %%
from tensorflow.keras import datasets, layers, models

ann = models.Sequential([
        layers.Dense(500, activation='relu'),
        layers.Dense(50, activation='relu'),
        layers.Dense(10, activation='softmax')    
    ])

# %%
from tensorflow.keras.optimizers import SGD,Adam
opt = SGD(lr=0.01)
ann.compile(optimizer=opt,
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history = ann.fit(X_train_feats, y_train, epochs=100, steps_per_epoch=len(X_train_feats)/32, validation_data=(X_test_feats, y_test), batch_size=32)
# Out:
# Train on 499 samples, validate on 125 samples
# Epoch 1/100
# 499/499 [==============================] - 2s 3ms/sample - loss: 2.1109 - accuracy: 0.2806 - val_loss: 1.9313 - val_accuracy: 0.4240
# Epoch 2/100
# 499/499 [==============================] - 0s 122us/sample - loss: 1.8140 - accuracy: 0.4309 - val_loss: 1.6847 - val_accuracy: 0.5520
# Epoch 3/100
# 499/499 [==============================] - 0s 122us/sample - loss: 1.6357 - accuracy: 0.5311 - val_loss: 1.5581 - val_accuracy: 0.4080
# Epoch 4/100
# 499/499 [==============================] - 0s 120us/sample - loss: 1.4810 - accuracy: 0.5972 - val_loss: 1.5109 - val_accuracy: 0.4000
# Epoch 5/100
# 499/499 [==============================] - 0s 102us/sample - loss: 1.3775 - accuracy: 0.6393 - val_loss: 1.3086 - val_accuracy: 0.6560
# Epoch 6/100
# 499/499 [==============================] - 0s 116us/sample - loss: 1.2684 - accuracy: 0.6874 - val_loss: 1.2283 - val_accuracy: 0.7040
# Epoch 7/100
# 499/499 [==============================] - 0s 102us/sample - loss: 1.1811 - accuracy: 0.7214 - val_loss: 1.1592 - val_accuracy: 0.6880
# Epoch 8/100
# 499/499 [==============================] - 0s 94us/sample - loss: 1.1114 - accuracy: 0.7234 - val_loss: 1.0814 - val_accuracy: 0.6640
# Epoch 9/100
# 499/499 [==============================] - 0s 90us/sample - loss: 1.0363 - accuracy: 0.7655 - val_loss: 1.0734 - val_accuracy: 0.5760
# Epoch 10/100
# 499/499 [==============================] - 0s 92us/sample - loss: 0.9759 - accuracy: 0.7555 - val_loss: 0.9703 - val_accuracy: 0.7600
# Epoch 11/100
# 499/499 [==============================] - 0s 94us/sample - loss: 0.9248 - accuracy: 0.7655 - val_loss: 1.0012 - val_accuracy: 0.8320
# Epoch 12/100
# 499/499 [==============================] - 0s 90us/sample - loss: 0.8751 - accuracy: 0.8277 - val_loss: 0.9097 - val_accuracy: 0.8320
# Epoch 13/100
# 499/499 [==============================] - 0s 90us/sample - loss: 0.8331 - accuracy: 0.8297 - val_loss: 0.9060 - val_accuracy: 0.6960
# Epoch 14/100
# 499/499 [==============================] - 0s 84us/sample - loss: 0.7922 - accuracy: 0.8417 - val_loss: 0.8331 - val_accuracy: 0.8240
# Epoch 15/100
# 499/499 [==============================] - 0s 92us/sample - loss: 0.7530 - accuracy: 0.8537 - val_loss: 0.7654 - val_accuracy: 0.9040
# Epoch 16/100
# 499/499 [==============================] - 0s 94us/sample - loss: 0.7186 - accuracy: 0.8577 - val_loss: 0.7449 - val_accuracy: 0.8080
# Epoch 17/100
# 499/499 [==============================] - 0s 90us/sample - loss: 0.6909 - accuracy: 0.8437 - val_loss: 0.7305 - val_accuracy: 0.8240
# Epoch 18/100
# 499/499 [==============================] - 0s 94us/sample - loss: 0.6626 - accuracy: 0.8717 - val_loss: 0.7188 - val_accuracy: 0.8240
# Epoch 19/100
# 499/499 [==============================] - 0s 90us/sample - loss: 0.6370 - accuracy: 0.8717 - val_loss: 0.7530 - val_accuracy: 0.8240
# Epoch 20/100
# 499/499 [==============================] - 0s 96us/sample - loss: 0.6121 - accuracy: 0.8938 - val_loss: 0.6523 - val_accuracy: 0.8880
# Epoch 21/100
# 499/499 [==============================] - 0s 98us/sample - loss: 0.5836 - accuracy: 0.8878 - val_loss: 0.6435 - val_accuracy: 0.8880
# Epoch 22/100
# 499/499 [==============================] - 0s 96us/sample - loss: 0.5689 - accuracy: 0.8958 - val_loss: 0.6163 - val_accuracy: 0.8960
# Epoch 23/100
# 499/499 [==============================] - 0s 96us/sample - loss: 0.5468 - accuracy: 0.8838 - val_loss: 0.5977 - val_accuracy: 0.8640
# Epoch 24/100
# 499/499 [==============================] - 0s 96us/sample - loss: 0.5189 - accuracy: 0.8878 - val_loss: 0.5388 - val_accuracy: 0.9280
# Epoch 25/100
# 499/499 [==============================] - 0s 100us/sample - loss: 0.5172 - accuracy: 0.9098 - val_loss: 0.5245 - val_accuracy: 0.9120
# Epoch 26/100
# 499/499 [==============================] - 0s 92us/sample - loss: 0.5012 - accuracy: 0.9018 - val_loss: 0.5424 - val_accuracy: 0.8720
# Epoch 27/100
# 499/499 [==============================] - 0s 90us/sample - loss: 0.4792 - accuracy: 0.9038 - val_loss: 0.5176 - val_accuracy: 0.8880
# Epoch 28/100
# 499/499 [==============================] - 0s 90us/sample - loss: 0.4608 - accuracy: 0.9138 - val_loss: 0.4792 - val_accuracy: 0.9120
# Epoch 29/100
# 499/499 [==============================] - 0s 96us/sample - loss: 0.4383 - accuracy: 0.9118 - val_loss: 0.4590 - val_accuracy: 0.9040
# Epoch 30/100
# 499/499 [==============================] - 0s 92us/sample - loss: 0.4215 - accuracy: 0.9218 - val_loss: 0.4403 - val_accuracy: 0.8800
# Epoch 31/100
# 499/499 [==============================] - 0s 84us/sample - loss: 0.4106 - accuracy: 0.9359 - val_loss: 0.4818 - val_accuracy: 0.9040
# Epoch 32/100
# 499/499 [==============================] - 0s 94us/sample - loss: 0.4022 - accuracy: 0.9198 - val_loss: 0.4574 - val_accuracy: 0.8960
# Epoch 33/100
# 499/499 [==============================] - 0s 96us/sample - loss: 0.3899 - accuracy: 0.9259 - val_loss: 0.4274 - val_accuracy: 0.8960
# Epoch 34/100
# 499/499 [==============================] - 0s 94us/sample - loss: 0.3819 - accuracy: 0.9178 - val_loss: 0.3854 - val_accuracy: 0.9200
# Epoch 35/100
# 499/499 [==============================] - 0s 86us/sample - loss: 0.3707 - accuracy: 0.9218 - val_loss: 0.4397 - val_accuracy: 0.9120
# Epoch 36/100
# 499/499 [==============================] - 0s 84us/sample - loss: 0.3558 - accuracy: 0.9279 - val_loss: 0.3927 - val_accuracy: 0.8880
# Epoch 37/100
# 499/499 [==============================] - 0s 90us/sample - loss: 0.3516 - accuracy: 0.9379 - val_loss: 0.3932 - val_accuracy: 0.9040
# Epoch 38/100
# 499/499 [==============================] - 0s 88us/sample - loss: 0.3394 - accuracy: 0.9399 - val_loss: 0.3634 - val_accuracy: 0.8960
# Epoch 39/100
# 499/499 [==============================] - 0s 88us/sample - loss: 0.3296 - accuracy: 0.9359 - val_loss: 0.3482 - val_accuracy: 0.9040
# Epoch 40/100
# 499/499 [==============================] - 0s 88us/sample - loss: 0.3184 - accuracy: 0.9379 - val_loss: 0.3283 - val_accuracy: 0.9280
# Epoch 41/100
# 499/499 [==============================] - 0s 86us/sample - loss: 0.3130 - accuracy: 0.9299 - val_loss: 0.3417 - val_accuracy: 0.9200
# Epoch 42/100
# 499/499 [==============================] - 0s 84us/sample - loss: 0.3056 - accuracy: 0.9459 - val_loss: 0.3552 - val_accuracy: 0.8960
# Epoch 43/100
# 499/499 [==============================] - 0s 90us/sample - loss: 0.2922 - accuracy: 0.9439 - val_loss: 0.3655 - val_accuracy: 0.9200
# Epoch 44/100
# 499/499 [==============================] - 0s 92us/sample - loss: 0.2893 - accuracy: 0.9539 - val_loss: 0.2998 - val_accuracy: 0.9200
# Epoch 45/100
# 499/499 [==============================] - 0s 88us/sample - loss: 0.2814 - accuracy: 0.9479 - val_loss: 0.2956 - val_accuracy: 0.9120
# Epoch 46/100
# 499/499 [==============================] - 0s 86us/sample - loss: 0.2736 - accuracy: 0.9499 - val_loss: 0.2923 - val_accuracy: 0.9120
# Epoch 47/100
# 499/499 [==============================] - 0s 82us/sample - loss: 0.2633 - accuracy: 0.9519 - val_loss: 0.2853 - val_accuracy: 0.9360
# Epoch 48/100
# 499/499 [==============================] - 0s 88us/sample - loss: 0.2634 - accuracy: 0.9499 - val_loss: 0.2878 - val_accuracy: 0.9200
# Epoch 49/100
# 499/499 [==============================] - 0s 90us/sample - loss: 0.2589 - accuracy: 0.9519 - val_loss: 0.3079 - val_accuracy: 0.9280
# Epoch 50/100
# 499/499 [==============================] - 0s 84us/sample - loss: 0.2514 - accuracy: 0.9519 - val_loss: 0.2867 - val_accuracy: 0.9120
# Epoch 51/100
# 499/499 [==============================] - 0s 84us/sample - loss: 0.2519 - accuracy: 0.9459 - val_loss: 0.2876 - val_accuracy: 0.9280
# Epoch 52/100
# 499/499 [==============================] - 0s 82us/sample - loss: 0.2400 - accuracy: 0.9579 - val_loss: 0.2944 - val_accuracy: 0.9040
# Epoch 53/100
# 499/499 [==============================] - 0s 90us/sample - loss: 0.2416 - accuracy: 0.9479 - val_loss: 0.3196 - val_accuracy: 0.8960
# Epoch 54/100
# 499/499 [==============================] - 0s 90us/sample - loss: 0.2340 - accuracy: 0.9519 - val_loss: 0.2629 - val_accuracy: 0.9040
# Epoch 55/100
# 499/499 [==============================] - 0s 94us/sample - loss: 0.2236 - accuracy: 0.9579 - val_loss: 0.2291 - val_accuracy: 0.9600
# Epoch 56/100
# 499/499 [==============================] - 0s 90us/sample - loss: 0.2218 - accuracy: 0.9519 - val_loss: 0.2415 - val_accuracy: 0.9600
# Epoch 57/100
# 499/499 [==============================] - 0s 86us/sample - loss: 0.2117 - accuracy: 0.9599 - val_loss: 0.2437 - val_accuracy: 0.9280
# Epoch 58/100
# 499/499 [==============================] - 0s 82us/sample - loss: 0.2103 - accuracy: 0.9679 - val_loss: 0.2364 - val_accuracy: 0.9440
# Epoch 59/100
# 499/499 [==============================] - 0s 90us/sample - loss: 0.2015 - accuracy: 0.9679 - val_loss: 0.2953 - val_accuracy: 0.9280
# Epoch 60/100
# 499/499 [==============================] - 0s 110us/sample - loss: 0.2043 - accuracy: 0.9539 - val_loss: 0.2319 - val_accuracy: 0.9440
# Epoch 61/100
# 499/499 [==============================] - 0s 94us/sample - loss: 0.1962 - accuracy: 0.9699 - val_loss: 0.2140 - val_accuracy: 0.9520
# Epoch 62/100
# 499/499 [==============================] - 0s 86us/sample - loss: 0.1951 - accuracy: 0.9599 - val_loss: 0.2596 - val_accuracy: 0.9120
# Epoch 63/100
# 499/499 [==============================] - 0s 86us/sample - loss: 0.1882 - accuracy: 0.9619 - val_loss: 0.2348 - val_accuracy: 0.9120
# Epoch 64/100
# 499/499 [==============================] - 0s 84us/sample - loss: 0.1848 - accuracy: 0.9679 - val_loss: 0.2220 - val_accuracy: 0.9440
# Epoch 65/100
# 499/499 [==============================] - 0s 82us/sample - loss: 0.1799 - accuracy: 0.9659 - val_loss: 0.2253 - val_accuracy: 0.9280
# Epoch 66/100
# 499/499 [==============================] - 0s 88us/sample - loss: 0.1803 - accuracy: 0.9659 - val_loss: 0.2874 - val_accuracy: 0.9040
# Epoch 67/100
# 499/499 [==============================] - 0s 82us/sample - loss: 0.1830 - accuracy: 0.9559 - val_loss: 0.2153 - val_accuracy: 0.9440
# Epoch 68/100
# 499/499 [==============================] - 0s 86us/sample - loss: 0.1692 - accuracy: 0.9699 - val_loss: 0.2136 - val_accuracy: 0.9360
# Epoch 69/100
# 499/499 [==============================] - 0s 84us/sample - loss: 0.1781 - accuracy: 0.9659 - val_loss: 0.2065 - val_accuracy: 0.9440
# Epoch 70/100
# 499/499 [==============================] - 0s 84us/sample - loss: 0.1676 - accuracy: 0.9619 - val_loss: 0.2402 - val_accuracy: 0.9360
# Epoch 71/100
# 499/499 [==============================] - 0s 84us/sample - loss: 0.1718 - accuracy: 0.9679 - val_loss: 0.2181 - val_accuracy: 0.9280
# Epoch 72/100
# 499/499 [==============================] - 0s 88us/sample - loss: 0.1586 - accuracy: 0.9679 - val_loss: 0.2041 - val_accuracy: 0.9280
# Epoch 73/100
# 499/499 [==============================] - 0s 86us/sample - loss: 0.1597 - accuracy: 0.9699 - val_loss: 0.1949 - val_accuracy: 0.9520
# Epoch 74/100
# 499/499 [==============================] - 0s 84us/sample - loss: 0.1551 - accuracy: 0.9719 - val_loss: 0.1875 - val_accuracy: 0.9600
# Epoch 75/100
# 499/499 [==============================] - 0s 90us/sample - loss: 0.1477 - accuracy: 0.9760 - val_loss: 0.1925 - val_accuracy: 0.9520
# Epoch 76/100
# 499/499 [==============================] - 0s 86us/sample - loss: 0.1560 - accuracy: 0.9619 - val_loss: 0.2059 - val_accuracy: 0.9440
# Epoch 77/100
# 499/499 [==============================] - 0s 92us/sample - loss: 0.1508 - accuracy: 0.9719 - val_loss: 0.1811 - val_accuracy: 0.9440
# Epoch 78/100
# 499/499 [==============================] - 0s 88us/sample - loss: 0.1506 - accuracy: 0.9699 - val_loss: 0.1948 - val_accuracy: 0.9200
# Epoch 79/100
# 499/499 [==============================] - 0s 86us/sample - loss: 0.1489 - accuracy: 0.9739 - val_loss: 0.1880 - val_accuracy: 0.9440
# Epoch 80/100
# 499/499 [==============================] - 0s 84us/sample - loss: 0.1411 - accuracy: 0.9780 - val_loss: 0.1706 - val_accuracy: 0.9680
# Epoch 81/100
# 499/499 [==============================] - 0s 86us/sample - loss: 0.1454 - accuracy: 0.9760 - val_loss: 0.1822 - val_accuracy: 0.9600
# Epoch 82/100
# 499/499 [==============================] - 0s 82us/sample - loss: 0.1371 - accuracy: 0.9739 - val_loss: 0.1722 - val_accuracy: 0.9520
# Epoch 83/100
# 499/499 [==============================] - 0s 84us/sample - loss: 0.1370 - accuracy: 0.9780 - val_loss: 0.2162 - val_accuracy: 0.9440
# Epoch 84/100
# 499/499 [==============================] - 0s 84us/sample - loss: 0.1344 - accuracy: 0.9780 - val_loss: 0.1769 - val_accuracy: 0.9600
# Epoch 85/100
# 499/499 [==============================] - 0s 86us/sample - loss: 0.1316 - accuracy: 0.9760 - val_loss: 0.1820 - val_accuracy: 0.9440
# Epoch 86/100
# 499/499 [==============================] - 0s 90us/sample - loss: 0.1295 - accuracy: 0.9800 - val_loss: 0.1790 - val_accuracy: 0.9440
# Epoch 87/100
# 499/499 [==============================] - 0s 82us/sample - loss: 0.1270 - accuracy: 0.9760 - val_loss: 0.1741 - val_accuracy: 0.9280
# Epoch 88/100
# 499/499 [==============================] - 0s 86us/sample - loss: 0.1241 - accuracy: 0.9820 - val_loss: 0.1561 - val_accuracy: 0.9600
# Epoch 89/100
# 499/499 [==============================] - 0s 90us/sample - loss: 0.1234 - accuracy: 0.9820 - val_loss: 0.1696 - val_accuracy: 0.9360
# Epoch 90/100
# 499/499 [==============================] - 0s 84us/sample - loss: 0.1265 - accuracy: 0.9719 - val_loss: 0.1752 - val_accuracy: 0.9440
# Epoch 91/100
# 499/499 [==============================] - 0s 86us/sample - loss: 0.1170 - accuracy: 0.9820 - val_loss: 0.1689 - val_accuracy: 0.9440
# Epoch 92/100
# 499/499 [==============================] - 0s 82us/sample - loss: 0.1161 - accuracy: 0.9780 - val_loss: 0.1599 - val_accuracy: 0.9600
# Epoch 93/100
# 499/499 [==============================] - 0s 84us/sample - loss: 0.1176 - accuracy: 0.9840 - val_loss: 0.1564 - val_accuracy: 0.9600
# Epoch 94/100
# 499/499 [==============================] - 0s 84us/sample - loss: 0.1136 - accuracy: 0.9800 - val_loss: 0.1537 - val_accuracy: 0.9520
# Epoch 95/100
# 499/499 [==============================] - 0s 84us/sample - loss: 0.1137 - accuracy: 0.9820 - val_loss: 0.1824 - val_accuracy: 0.9520
# Epoch 96/100
# 499/499 [==============================] - 0s 84us/sample - loss: 0.1137 - accuracy: 0.9840 - val_loss: 0.1512 - val_accuracy: 0.9600
# Epoch 97/100
# 499/499 [==============================] - 0s 84us/sample - loss: 0.1122 - accuracy: 0.9880 - val_loss: 0.1498 - val_accuracy: 0.9520
# Epoch 98/100
# 499/499 [==============================] - 0s 86us/sample - loss: 0.1094 - accuracy: 0.9880 - val_loss: 0.1899 - val_accuracy: 0.9520
# Epoch 99/100
# 499/499 [==============================] - 0s 82us/sample - loss: 0.1099 - accuracy: 0.9820 - val_loss: 0.1365 - val_accuracy: 0.9680
# Epoch 100/100
# 499/499 [==============================] - 0s 88us/sample - loss: 0.1072 - accuracy: 0.9880 - val_loss: 0.1562 - val_accuracy: 0.9520

# %%
ann.evaluate(X_test_feats,y_test)
# Out:
# 125/125 [==============================] - 0s 144us/sample - loss: 0.1562 - accuracy: 0.9520
# [0.1561609871983528, 0.952]

# %%
from sklearn.metrics import confusion_matrix , classification_report
import numpy as np
y_pred = ann.predict(X_test_feats)
y_pred_classes = [np.argmax(element) for element in y_pred]

print("Classification Report: \n", classification_report(y_test, y_pred_classes))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        12
#            1       1.00      1.00      1.00        13
#            2       0.86      0.92      0.89        13
#            3       0.94      1.00      0.97        15
#            4       1.00      1.00      1.00        20
#            5       1.00      1.00      1.00        11
#            6       1.00      1.00      1.00         7
#            7       1.00      1.00      1.00         7
#            8       0.80      1.00      0.89        12
#            9       1.00      0.67      0.80        15
#
#     accuracy                           0.95       125
#    macro avg       0.96      0.96      0.95       125
# weighted avg       0.96      0.95      0.95       125

# %%
#y_pred = ann.predict(X_test_feats)
#y_pred = le.inverse_transform(y_pred)
#y_test = le.inverse_transform(y_test)
print('Percentage correct: ', 100*np.sum(y_pred_classes == y_test)/len(y_test))
# Out:
# Percentage correct:  95.2

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import pandas as pd

cmx=confusion_matrix(y_test, y_pred_classes, labels=labelsN)

df2 = pd.DataFrame(cmx, columns=labels, index=labels)
df2.columns.name = 'prediction'
df2.index.name = 'label'
df2
# Out:
# prediction                       Bifidobacterium spp(-ve)  \
# label
# Bifidobacterium spp(-ve)                               12
# Candida Albicans(-ve)                                   0
# Enterococcus faecalis(-ve)                              0
# Escherichia Coli(+ve)                                   0
# Fusobacterium(+ve)                                      0
# Lactobacillus Gasseri(-ve)                              0
# Listeria Monocytogenes(-ve)                             0
# Pseudomonas Aeruginosa(+ve)                             0
# Staphylococcus Epidermidis(-ve)                         0
# Streptococcus Agalactiae(-ve)                           0
#
# prediction                       Candida Albicans(-ve)  \
# label
# Bifidobacterium spp(-ve)                             0
# Candida Albicans(-ve)                               13
# Enterococcus faecalis(-ve)                           0
# Escherichia Coli(+ve)                                0
# Fusobacterium(+ve)                                   0
# Lactobacillus Gasseri(-ve)                           0
# Listeria Monocytogenes(-ve)                          0
# Pseudomonas Aeruginosa(+ve)                          0
# Staphylococcus Epidermidis(-ve)                      0
# Streptococcus Agalactiae(-ve)                        0
#
# prediction                       Enterococcus faecalis(-ve)  \
# label
# Bifidobacterium spp(-ve)                                  0
# Candida Albicans(-ve)                                     0
# Enterococcus faecalis(-ve)                               12
# Escherichia Coli(+ve)                                     0
# Fusobacterium(+ve)                                        0
# Lactobacillus Gasseri(-ve)                                0
# Listeria Monocytogenes(-ve)                               0
# Pseudomonas Aeruginosa(+ve)                               0
# Staphylococcus Epidermidis(-ve)                           0
# Streptococcus Agalactiae(-ve)                             2
#
# prediction                       Escherichia Coli(+ve)  Fusobacterium(+ve)  \
# label
# Bifidobacterium spp(-ve)                             0                   0
# Candida Albicans(-ve)                                0                   0
# Enterococcus faecalis(-ve)                           1                   0
# Escherichia Coli(+ve)                               15                   0
# Fusobacterium(+ve)                                   0                  20
# Lactobacillus Gasseri(-ve)                           0                   0
# Listeria Monocytogenes(-ve)                          0                   0
# Pseudomonas Aeruginosa(+ve)                          0                   0
# Staphylococcus Epidermidis(-ve)                      0                   0
# Streptococcus Agalactiae(-ve)                        0                   0
#
# prediction                       Lactobacillus Gasseri(-ve)  \
# label
# Bifidobacterium spp(-ve)                                  0
# Candida Albicans(-ve)                                     0
# Enterococcus faecalis(-ve)                                0
# Escherichia Coli(+ve)                                     0
# Fusobacterium(+ve)                                        0
# Lactobacillus Gasseri(-ve)                               11
# Listeria Monocytogenes(-ve)                               0
# Pseudomonas Aeruginosa(+ve)                               0
# Staphylococcus Epidermidis(-ve)                           0
# Streptococcus Agalactiae(-ve)                             0
#
# prediction                       Listeria Monocytogenes(-ve)  \
# label
# Bifidobacterium spp(-ve)                                   0
# Candida Albicans(-ve)                                      0
# Enterococcus faecalis(-ve)                                 0
# Escherichia Coli(+ve)                                      0
# Fusobacterium(+ve)                                         0
# Lactobacillus Gasseri(-ve)                                 0
# Listeria Monocytogenes(-ve)                                7
# Pseudomonas Aeruginosa(+ve)                                0
# Staphylococcus Epidermidis(-ve)                            0
# Streptococcus Agalactiae(-ve)                              0
#
# prediction                       Pseudomonas Aeruginosa(+ve)  \
# label
# Bifidobacterium spp(-ve)                                   0
# Candida Albicans(-ve)                                      0
# Enterococcus faecalis(-ve)                                 0
# Escherichia Coli(+ve)                                      0
# Fusobacterium(+ve)                                         0
# Lactobacillus Gasseri(-ve)                                 0
# Listeria Monocytogenes(-ve)                                0
# Pseudomonas Aeruginosa(+ve)                                7
# Staphylococcus Epidermidis(-ve)                            0
# Streptococcus Agalactiae(-ve)                              0
#
# prediction                       Staphylococcus Epidermidis(-ve)  \
# label
# Bifidobacterium spp(-ve)                                       0
# Candida Albicans(-ve)                                          0
# Enterococcus faecalis(-ve)                                     0
# Escherichia Coli(+ve)                                          0
# Fusobacterium(+ve)                                             0
# Lactobacillus Gasseri(-ve)                                     0
# Listeria Monocytogenes(-ve)                                    0
# Pseudomonas Aeruginosa(+ve)                                    0
# Staphylococcus Epidermidis(-ve)                               12
# Streptococcus Agalactiae(-ve)                                  3
#
# prediction                       Streptococcus Agalactiae(-ve)
# label
# Bifidobacterium spp(-ve)                                     0
# Candida Albicans(-ve)                                        0
# Enterococcus faecalis(-ve)                                   0
# Escherichia Coli(+ve)                                        0
# Fusobacterium(+ve)                                           0
# Lactobacillus Gasseri(-ve)                                   0
# Listeria Monocytogenes(-ve)                                  0
# Pseudomonas Aeruginosa(+ve)                                  0
# Staphylococcus Epidermidis(-ve)                              0
# Streptococcus Agalactiae(-ve)                               10

# %%
tp=0
fn=0
tn=0
fp=0

for i in range(len(labels)):
    for k in range(len(labels)):
        if k == i:
            tp+=cmx[i][k]
            if cmx[i][i]==0:
                fn+=1
        else:
            if cmx[i][k]!=0:
                fp+=cmx[i][k]
            else:
                tn+=1

                

print('TP:', tp)
print('FP:', fp)
print('TN:', tn)
print('FN:', fn)

prec=(tp/(tp+fp))*100
recall=(tp/(tp+fn))*100
acc=((tp+tn)/(tp+fp+tn+fn))*100
print('Precision:' + str(prec) +
     '\nRecall:' + str(recall) +
      '\nAccuracy:' + str(acc))
# Out:
# TP: 119
# FP: 6
# TN: 87
# FN: 0
# Precision:95.19999999999999
# Recall:100.0
# Accuracy:97.16981132075472

# %%
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['training accuracy', 'validation accuracy'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['training loss', 'validation loss'], loc='upper left')
plt.show()

# %%
n=np.random.randint(0, X_test.shape[0])
img = X_test_resize[n]
plt.imshow(img)
input_img = np.expand_dims(img, axis=0) #Expand dims so the input is (num images, x, y, c)
input_img_feature=VGG_model.predict(input_img)
input_img_features=input_img_feature.reshape(input_img_feature.shape[0], -1)
y_pred_rand = ann.predict(input_img_features)[0]

y_pred_rand_class = np.argmax(y_pred_rand)
y_pred_rand_class=le.inverse_transform([y_pred_rand_class])
y_actual = le.inverse_transform([y_test[n]])

print("The prediction for this image is: ", y_pred_rand_class)
print("The actual label for this image is: ", y_actual)
# Out:
# The prediction for this image is:  ['Enterococcus faecalis(-ve)']
# The actual label for this image is:  ['Enterococcus faecalis(-ve)']
