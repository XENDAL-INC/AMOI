# %%
# %matplotlib inline

import tensorflow as tf
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.applications.vgg16 import VGG16
from sklearn import preprocessing
import matplotlib.pyplot as plt
import numpy as np
import os
import pprint
pp = pprint.PrettyPrinter(indent=4)

# %%
import joblib
from skimage.io import imread
from skimage.transform import resize

gramPositive_labels=['Escherichia Coli(+ve)',
 'Fusobacterium(+ve)',
 'Pseudomonas Aeruginosa(+ve)']
gramNegative_labels=['Bifidobacterium spp(-ve)',
 'Candida Albicans(-ve)',
 'Enterococcus faecalis(-ve)',
 'Lactobacillus Gasseri(-ve)',
 'Listeria Monocytogenes(-ve)',
 'Staphylococcus Epidermidis(-ve)',
 'Streptococcus Agalactiae(-ve)']

all_labels=['Bifidobacterium spp(-ve)',
 'Candida Albicans(-ve)',
 'Enterococcus faecalis(-ve)',
 'Escherichia Coli(+ve)',
 'Fusobacterium(+ve)',
 'Lactobacillus Gasseri(-ve)',
 'Listeria Monocytogenes(-ve)',
 'Pseudomonas Aeruginosa(+ve)',
 'Staphylococcus Epidermidis(-ve)',
 'Streptococcus Agalactiae(-ve)']

labels = all_labels

labelsN = []
i=0
for label in labels:
    labelsN.append(int(i))
    i=i+1

def resize_all(src, pklname, include, width=2048, height=1532):
    """
    load images from path, resize them and write them as arrays to a dictionary, 
    together with labels and metadata. The dictionary is written to a pickle file 
    named '{pklname}_{width}x{height}px.pkl'.
     
    Parameter
    ---------
    src: str
        path to data
    pklname: str
        path to output file
    width: int
        target width of the image in pixels
    include: set[str]
        set containing str
    """
     
    height = height if height is not None else width
     
    data = dict()
    data['description'] = 'bacteria images'.format(int(width), int(height))
    data['label'] = []
    data['filename'] = []
    data['data'] = []
     
    pklname = f"{pklname}_{width}x{height}px.pkl"
    
    # read all images in PATH, resize and write to DESTINATION_PATH
    for subdir in os.listdir(src):
        if subdir in include:
            print(subdir)
            current_path = os.path.join(src, subdir)
 
            for file in os.listdir(current_path):
                if file[-3:] in {'jpg', 'png'}:
                    im = imread(os.path.join(current_path, file))
                    #im = resize(im, (width, height)) #[:,:,::-1]
                    data['label'].append(subdir)
                    data['filename'].append(file)
                    data['data'].append(im)
                    imH = np.fliplr(im)
                    imV = np.flipud(im)
                    #flipH
                    data['label'].append(subdir)
                    data['filename'].append("flipH_" + file)
                    data['data'].append(imH)
                    #flipV
                    data['label'].append(subdir)
                    data['filename'].append("flipV_" + file)
                    data['data'].append(imV)

 
        joblib.dump(data, pklname)

# %%
# modify to fit your system
data_path = 'D:/Xendal/University/Grad/Dataset'
os.listdir(data_path)
# Out:
# ['Bifidobacterium spp(-ve)',
#  'Candida Albicans(-ve)',
#  'Enterococcus faecalis(-ve)',
#  'Escherichia Coli(+ve)',
#  'Fusobacterium(+ve)',
#  'Lactobacillus Gasseri(-ve)',
#  'Listeria Monocytogenes(-ve)',
#  'Pseudomonas Aeruginosa(+ve)',
#  'Staphylococcus Epidermidis(-ve)',
#  'Streptococcus Agalactiae(-ve)']

# %%
base_name = 'D:/Xendal/University/Grad/datasetPickle/augmented_bacteria'
width = 2048
height = 1532

gramPositive_include={'Escherichia Coli(+ve)',
 'Fusobacterium(+ve)',
 'Pseudomonas Aeruginosa(+ve)'}

gramNegative_include={'Bifidobacterium spp(-ve)',
 'Candida Albicans(-ve)',
 'Enterococcus faecalis(-ve)',
 'Lactobacillus Gasseri(-ve)',
 'Listeria Monocytogenes(-ve)',
 'Staphylococcus Epidermidis(-ve)',
 'Streptococcus Agalactiae(-ve)'}

all_include={'Bifidobacterium spp(-ve)',
 'Candida Albicans(-ve)',
 'Enterococcus faecalis(-ve)',
 'Escherichia Coli(+ve)',
 'Fusobacterium(+ve)',
 'Lactobacillus Gasseri(-ve)',
 'Listeria Monocytogenes(-ve)',
 'Pseudomonas Aeruginosa(+ve)',
 'Staphylococcus Epidermidis(-ve)',
 'Streptococcus Agalactiae(-ve)'}

include = all_include
   
#resize_all(src=data_path, pklname=base_name, width=width, include=include,)

# %%
from collections import Counter
 
data = joblib.load(f'{base_name}_{width}x{height}px.pkl')
 
print('number of samples: ', len(data['data']))
print('keys: ', list(data.keys()))
print('description: ', data['description'])
print('image shape: ', data['data'][0].shape)
print('labels:', np.unique(data['label']))
 
Counter(data['label'])
# Out:
# number of samples:  624
# keys:  ['description', 'label', 'filename', 'data']
# description:  bacteria images
# image shape:  (1532, 2048, 3)
# labels: ['Bifidobacterium spp(-ve)' 'Candida Albicans(-ve)'
#  'Enterococcus faecalis(-ve)' 'Escherichia Coli(+ve)' 'Fusobacterium(+ve)'
#  'Lactobacillus Gasseri(-ve)' 'Listeria Monocytogenes(-ve)'
#  'Pseudomonas Aeruginosa(+ve)' 'Staphylococcus Epidermidis(-ve)'
#  'Streptococcus Agalactiae(-ve)']
# Counter({'Bifidobacterium spp(-ve)': 69,
#          'Candida Albicans(-ve)': 60,
#          'Enterococcus faecalis(-ve)': 60,
#          'Escherichia Coli(+ve)': 60,
#          'Fusobacterium(+ve)': 69,
#          'Lactobacillus Gasseri(-ve)': 60,
#          'Listeria Monocytogenes(-ve)': 66,
#          'Pseudomonas Aeruginosa(+ve)': 60,
#          'Staphylococcus Epidermidis(-ve)': 60,
#          'Streptococcus Agalactiae(-ve)': 60})

# %%
# use np.unique to get all unique values in the list of labels
labels = np.unique(data['label'])
 
# set up the matplotlib figure and axes, based on the number of labels
fig, axes = plt.subplots(1, len(labels))
fig.set_size_inches(15,4)
fig.tight_layout()
 
# make a plot for every label (equipment) type. The index method returns the 
# index of the first item corresponding to its search string, label in this case
for ax, label in zip(axes, labels):
    idx = data['label'].index(label)
     
    ax.imshow(data['data'][idx])
    ax.axis('off')
    ax.set_title(label)

# %%
X = np.array(data['data'])
y = np.array(data['label'])

# %%
le = preprocessing.LabelEncoder()
le.fit(y)
y_labels_encoded = le.transform(y)

# %%
from sklearn.model_selection import train_test_split
 
X_train, X_test, y_train, y_test = train_test_split(
    X, 
    y_labels_encoded, 
    test_size=0.2, 
    shuffle=True,
    random_state=42,
)

# %%
def plot_bar(y, loc='left', relative=True):
    width = 0.35
    if loc == 'left':
        n = -0.5
    elif loc == 'right':
        n = 0.5
     
    # calculate counts per type and sort, to ensure their order
    unique, counts = np.unique(y, return_counts=True)
    sorted_index = np.argsort(unique)
    unique = unique[sorted_index]
     
    if relative:
        # plot as a percentage
        counts = 100*counts[sorted_index]/len(y)
        ylabel_text = '% count'
    else:
        # plot counts
        counts = counts[sorted_index]
        ylabel_text = 'count'
         
    xtemp = np.arange(len(unique))
     
    plt.bar(xtemp + n*width, counts, align='center', alpha=.7, width=width)
    plt.xticks(xtemp, unique, rotation=45)
    plt.xlabel('equipment type')
    plt.ylabel(ylabel_text)
    
plt.suptitle('relative amount of photos per type')
plot_bar(y_train, loc='left')
plot_bar(y_test, loc='right')
plt.legend([
    'train ({0} photos)'.format(len(y_train)), 
    'test ({0} photos)'.format(len(y_test))
]);

# %%
from sklearn.base import BaseEstimator, TransformerMixin
from skimage import color
from skimage.feature import hog
from sklearn import svm
from sklearn.metrics import classification_report,accuracy_score

# %%
class ResizeTransformer(BaseEstimator, TransformerMixin):
    """
    Scales array to 1/3
    """
 
    def __init__(self):
        pass
 
    def fit(self, X, y=None):
        """returns itself"""
        return self
 
    def transform(self, X, y=None):
        """perform the transformation and return an array"""
        return np.array([resize(img, (img.shape[0] // 6.8, img.shape[1] // 6.8), anti_aliasing='True') for img in X])

# %%
from sklearn.linear_model import SGDClassifier
from sklearn.model_selection import cross_val_predict
from sklearn.preprocessing import StandardScaler, Normalizer
import skimage
import cv2 as cv
from skimage.transform import rescale

resizify = ResizeTransformer()

X_train_resize=resizify.fit_transform(X_train)

print(X_train.shape)
print(X_train_resize.shape)
# Out:
# (499, 1532, 2048, 3)
# (499, 225, 301, 3)

# %%
X_test_resize=resizify.fit_transform(X_test)

print(X_test.shape)
print(X_test_resize.shape)
# Out:
# (125, 1532, 2048, 3)
# (125, 225, 301, 3)

# %%
tf.keras.backend.clear_session()
cnn = models.Sequential()
cnn.add(layers.Conv2D(64, (3,3), activation='relu', input_shape=(225,301,3)))
cnn.add(layers.MaxPooling2D((2,2)))

cnn.add(layers.Conv2D(128, (3,3), activation='relu'))
cnn.add(layers.MaxPooling2D((2,2)))

cnn.add(layers.Conv2D(256, (3,3), activation='relu'))
cnn.add(layers.MaxPooling2D((2,2)))

cnn.add(layers.Conv2D(512, (3,3), activation='relu'))
cnn.add(layers.MaxPooling2D((2,2)))

cnn.add(layers.Conv2D(512, (3,3), activation='relu'))
cnn.add(layers.MaxPooling2D((2,2)))

# %%
cnn.add(layers.Flatten())
cnn.add(layers.Dense(500, activation='relu'))
cnn.add(layers.Dense(100, activation='relu'))
cnn.add(layers.Dense(10, activation='softmax'))
cnn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 223, 299, 64)      1792
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 111, 149, 64)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 109, 147, 128)     73856
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 54, 73, 128)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 52, 71, 256)       295168
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 26, 35, 256)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 24, 33, 512)       1180160
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 12, 16, 512)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 10, 14, 512)       2359808
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 5, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 17920)             0
# _________________________________________________________________
# dense (Dense)                (None, 500)               8960500
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               50100
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                1010
# =================================================================
# Total params: 12,922,394
# Trainable params: 12,922,394
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import SGD,Adam
opt = SGD(lr=0.01)
cnn.compile(optimizer=opt,
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history = cnn.fit(X_train_resize, y_train, epochs=100, steps_per_epoch=len(X_train_resize)/32, validation_data=(X_test_resize, y_test), batch_size=32)
# Out:
# Train on 499 samples, validate on 125 samples
# Epoch 1/100
# 499/499 [==============================] - 77s 155ms/sample - loss: 2.3034 - accuracy: 0.1042 - val_loss: 2.3057 - val_accuracy: 0.0960
# Epoch 2/100
# 499/499 [==============================] - 76s 151ms/sample - loss: 2.2985 - accuracy: 0.1343 - val_loss: 2.3095 - val_accuracy: 0.0560
# Epoch 3/100
# 499/499 [==============================] - 76s 152ms/sample - loss: 2.2959 - accuracy: 0.1383 - val_loss: 2.3095 - val_accuracy: 0.0560
# Epoch 4/100
# 499/499 [==============================] - 76s 151ms/sample - loss: 2.2923 - accuracy: 0.1182 - val_loss: 2.3076 - val_accuracy: 0.0960
# Epoch 5/100
# 499/499 [==============================] - 76s 152ms/sample - loss: 2.2908 - accuracy: 0.1503 - val_loss: 2.3088 - val_accuracy: 0.0560
# Epoch 6/100
# 499/499 [==============================] - 75s 151ms/sample - loss: 2.2879 - accuracy: 0.1263 - val_loss: 2.3062 - val_accuracy: 0.0560
# Epoch 7/100
# 499/499 [==============================] - 75s 151ms/sample - loss: 2.2846 - accuracy: 0.1202 - val_loss: 2.3012 - val_accuracy: 0.0880
# Epoch 8/100
# 499/499 [==============================] - 76s 153ms/sample - loss: 2.2817 - accuracy: 0.1423 - val_loss: 2.3013 - val_accuracy: 0.0560
# Epoch 9/100
# 499/499 [==============================] - 76s 153ms/sample - loss: 2.2773 - accuracy: 0.1503 - val_loss: 2.2961 - val_accuracy: 0.0560
# Epoch 10/100
# 499/499 [==============================] - 76s 153ms/sample - loss: 2.2737 - accuracy: 0.1503 - val_loss: 2.2899 - val_accuracy: 0.1360
# Epoch 11/100
# 499/499 [==============================] - 75s 151ms/sample - loss: 2.2677 - accuracy: 0.1884 - val_loss: 2.2873 - val_accuracy: 0.0720
# Epoch 12/100
# 499/499 [==============================] - 76s 152ms/sample - loss: 2.2605 - accuracy: 0.1623 - val_loss: 2.2991 - val_accuracy: 0.0560
# Epoch 13/100
# 499/499 [==============================] - 76s 153ms/sample - loss: 2.2532 - accuracy: 0.1844 - val_loss: 2.2866 - val_accuracy: 0.2160
# Epoch 14/100
# 499/499 [==============================] - 75s 150ms/sample - loss: 2.2434 - accuracy: 0.2425 - val_loss: 2.2703 - val_accuracy: 0.0880
# Epoch 15/100
# 499/499 [==============================] - 75s 150ms/sample - loss: 2.2260 - accuracy: 0.1924 - val_loss: 2.2923 - val_accuracy: 0.0560
# Epoch 16/100
# 499/499 [==============================] - 75s 151ms/sample - loss: 2.1902 - accuracy: 0.2806 - val_loss: 2.3173 - val_accuracy: 0.0960
# Epoch 17/100
# 499/499 [==============================] - 75s 151ms/sample - loss: 2.2035 - accuracy: 0.2024 - val_loss: 2.2559 - val_accuracy: 0.1360
# Epoch 18/100
# 499/499 [==============================] - 75s 151ms/sample - loss: 2.1758 - accuracy: 0.2345 - val_loss: 2.1455 - val_accuracy: 0.2560
# Epoch 19/100
# 499/499 [==============================] - 75s 150ms/sample - loss: 2.1898 - accuracy: 0.2525 - val_loss: 2.3988 - val_accuracy: 0.0560
# Epoch 20/100
# 499/499 [==============================] - 76s 152ms/sample - loss: 2.1554 - accuracy: 0.2164 - val_loss: 2.0952 - val_accuracy: 0.2160
# Epoch 21/100
# 499/499 [==============================] - 75s 150ms/sample - loss: 2.1432 - accuracy: 0.1864 - val_loss: 2.2308 - val_accuracy: 0.1200
# Epoch 22/100
# 499/499 [==============================] - 75s 149ms/sample - loss: 2.1165 - accuracy: 0.2665 - val_loss: 2.2483 - val_accuracy: 0.1120
# Epoch 23/100
# 499/499 [==============================] - 75s 150ms/sample - loss: 2.1606 - accuracy: 0.2184 - val_loss: 2.1270 - val_accuracy: 0.1120
# Epoch 24/100
# 499/499 [==============================] - 75s 149ms/sample - loss: 2.0825 - accuracy: 0.2525 - val_loss: 2.2745 - val_accuracy: 0.1600
# Epoch 25/100
# 499/499 [==============================] - 74s 149ms/sample - loss: 2.0334 - accuracy: 0.3046 - val_loss: 2.1265 - val_accuracy: 0.1440
# Epoch 26/100
# 499/499 [==============================] - 75s 149ms/sample - loss: 2.0169 - accuracy: 0.2485 - val_loss: 2.1806 - val_accuracy: 0.1200
# Epoch 27/100
# 499/499 [==============================] - 74s 149ms/sample - loss: 2.0720 - accuracy: 0.2685 - val_loss: 2.3397 - val_accuracy: 0.0960
# Epoch 28/100
# 499/499 [==============================] - 74s 148ms/sample - loss: 2.0748 - accuracy: 0.2084 - val_loss: 2.0410 - val_accuracy: 0.2320
# Epoch 29/100
# 499/499 [==============================] - 75s 150ms/sample - loss: 1.9764 - accuracy: 0.3086 - val_loss: 1.8332 - val_accuracy: 0.2480
# Epoch 30/100
# 499/499 [==============================] - 75s 150ms/sample - loss: 2.0132 - accuracy: 0.2766 - val_loss: 2.1239 - val_accuracy: 0.1280
# Epoch 31/100
# 499/499 [==============================] - 74s 149ms/sample - loss: 1.9388 - accuracy: 0.2946 - val_loss: 2.2933 - val_accuracy: 0.1440
# Epoch 32/100
# 499/499 [==============================] - 75s 150ms/sample - loss: 1.9271 - accuracy: 0.2725 - val_loss: 2.4468 - val_accuracy: 0.1120
# Epoch 33/100
# 499/499 [==============================] - 74s 149ms/sample - loss: 2.1784 - accuracy: 0.2124 - val_loss: 2.2445 - val_accuracy: 0.0880
# Epoch 34/100
# 499/499 [==============================] - 74s 148ms/sample - loss: 1.8131 - accuracy: 0.3727 - val_loss: 1.8148 - val_accuracy: 0.2000
# Epoch 35/100
# 499/499 [==============================] - 74s 149ms/sample - loss: 1.7465 - accuracy: 0.3547 - val_loss: 2.0962 - val_accuracy: 0.2240
# Epoch 36/100
# 499/499 [==============================] - 74s 149ms/sample - loss: 1.7613 - accuracy: 0.3367 - val_loss: 1.5826 - val_accuracy: 0.4400
# Epoch 37/100
# 499/499 [==============================] - 74s 149ms/sample - loss: 1.8360 - accuracy: 0.3768 - val_loss: 1.7740 - val_accuracy: 0.2400
# Epoch 38/100
# 499/499 [==============================] - 75s 149ms/sample - loss: 1.8273 - accuracy: 0.3226 - val_loss: 1.6399 - val_accuracy: 0.4320
# Epoch 39/100
# 499/499 [==============================] - 74s 149ms/sample - loss: 1.7042 - accuracy: 0.3768 - val_loss: 1.7954 - val_accuracy: 0.2000
# Epoch 40/100
# 499/499 [==============================] - 76s 152ms/sample - loss: 1.6099 - accuracy: 0.4108 - val_loss: 1.4845 - val_accuracy: 0.4080
# Epoch 41/100
# 499/499 [==============================] - 77s 155ms/sample - loss: 1.6631 - accuracy: 0.4429 - val_loss: 1.6312 - val_accuracy: 0.3360
# Epoch 42/100
# 499/499 [==============================] - 74s 149ms/sample - loss: 1.8752 - accuracy: 0.3287 - val_loss: 1.8005 - val_accuracy: 0.2880
# Epoch 43/100
# 499/499 [==============================] - 74s 148ms/sample - loss: 1.5550 - accuracy: 0.4770 - val_loss: 1.6527 - val_accuracy: 0.3280
# Epoch 44/100
# 499/499 [==============================] - 75s 150ms/sample - loss: 1.4811 - accuracy: 0.4469 - val_loss: 1.4517 - val_accuracy: 0.3680
# Epoch 45/100
# 499/499 [==============================] - 75s 150ms/sample - loss: 1.5727 - accuracy: 0.4629 - val_loss: 1.9177 - val_accuracy: 0.2080
# Epoch 46/100
# 499/499 [==============================] - 74s 149ms/sample - loss: 1.5542 - accuracy: 0.4269 - val_loss: 1.7411 - val_accuracy: 0.2640
# Epoch 47/100
# 499/499 [==============================] - 74s 149ms/sample - loss: 1.4199 - accuracy: 0.4629 - val_loss: 1.2710 - val_accuracy: 0.5040
# Epoch 48/100
# 499/499 [==============================] - 74s 149ms/sample - loss: 1.5544 - accuracy: 0.4429 - val_loss: 1.5993 - val_accuracy: 0.3200
# Epoch 49/100
# 499/499 [==============================] - 74s 149ms/sample - loss: 1.3336 - accuracy: 0.4609 - val_loss: 1.3831 - val_accuracy: 0.5440
# Epoch 50/100
# 499/499 [==============================] - 74s 149ms/sample - loss: 1.3922 - accuracy: 0.5030 - val_loss: 1.2338 - val_accuracy: 0.4720
# Epoch 51/100
# 499/499 [==============================] - 74s 149ms/sample - loss: 1.3274 - accuracy: 0.4970 - val_loss: 1.1990 - val_accuracy: 0.6080
# Epoch 52/100
# 499/499 [==============================] - 74s 149ms/sample - loss: 1.4740 - accuracy: 0.4409 - val_loss: 1.3987 - val_accuracy: 0.3920
# Epoch 53/100
# 499/499 [==============================] - 75s 150ms/sample - loss: 1.5382 - accuracy: 0.5210 - val_loss: 1.5621 - val_accuracy: 0.2960
# Epoch 54/100
# 499/499 [==============================] - 74s 149ms/sample - loss: 1.4132 - accuracy: 0.4549 - val_loss: 1.4068 - val_accuracy: 0.4160
# Epoch 55/100
# 499/499 [==============================] - 74s 149ms/sample - loss: 1.1929 - accuracy: 0.5230 - val_loss: 1.6822 - val_accuracy: 0.3840
# Epoch 56/100
# 499/499 [==============================] - 75s 150ms/sample - loss: 1.1306 - accuracy: 0.5531 - val_loss: 1.3724 - val_accuracy: 0.4080
# Epoch 57/100
# 499/499 [==============================] - 75s 149ms/sample - loss: 1.1207 - accuracy: 0.5551 - val_loss: 1.1947 - val_accuracy: 0.6160
# Epoch 58/100
# 499/499 [==============================] - 75s 150ms/sample - loss: 1.2228 - accuracy: 0.5471 - val_loss: 1.3318 - val_accuracy: 0.3600
# Epoch 59/100
# 499/499 [==============================] - 74s 149ms/sample - loss: 0.9604 - accuracy: 0.6313 - val_loss: 1.9178 - val_accuracy: 0.3520
# Epoch 60/100
# 499/499 [==============================] - 74s 149ms/sample - loss: 1.1421 - accuracy: 0.5531 - val_loss: 3.6704 - val_accuracy: 0.2080
# Epoch 61/100
# 499/499 [==============================] - 75s 149ms/sample - loss: 1.1347 - accuracy: 0.5872 - val_loss: 0.8998 - val_accuracy: 0.6160
# Epoch 62/100
# 499/499 [==============================] - 74s 149ms/sample - loss: 1.0880 - accuracy: 0.5972 - val_loss: 1.1525 - val_accuracy: 0.4960
# Epoch 63/100
# 499/499 [==============================] - 75s 150ms/sample - loss: 0.9352 - accuracy: 0.6593 - val_loss: 0.8324 - val_accuracy: 0.7120
# Epoch 64/100
# 499/499 [==============================] - 75s 150ms/sample - loss: 0.7717 - accuracy: 0.7074 - val_loss: 2.5231 - val_accuracy: 0.2240
# Epoch 65/100
# 499/499 [==============================] - 74s 149ms/sample - loss: 1.1747 - accuracy: 0.5752 - val_loss: 1.8076 - val_accuracy: 0.3600
# Epoch 66/100
# 499/499 [==============================] - 74s 149ms/sample - loss: 1.0967 - accuracy: 0.5752 - val_loss: 0.9802 - val_accuracy: 0.6320
# Epoch 67/100
# 499/499 [==============================] - 74s 149ms/sample - loss: 0.6678 - accuracy: 0.7275 - val_loss: 0.8172 - val_accuracy: 0.7200
# Epoch 68/100
# 499/499 [==============================] - 75s 150ms/sample - loss: 1.9713 - accuracy: 0.4148 - val_loss: 1.7105 - val_accuracy: 0.2480
# Epoch 69/100
# 499/499 [==============================] - 74s 149ms/sample - loss: 1.2898 - accuracy: 0.5230 - val_loss: 1.0496 - val_accuracy: 0.5920
# Epoch 70/100
# 499/499 [==============================] - 74s 149ms/sample - loss: 0.8355 - accuracy: 0.6874 - val_loss: 1.4934 - val_accuracy: 0.4480
# Epoch 71/100
# 499/499 [==============================] - 74s 149ms/sample - loss: 1.1329 - accuracy: 0.6293 - val_loss: 1.0148 - val_accuracy: 0.5920
# Epoch 72/100
# 499/499 [==============================] - 74s 149ms/sample - loss: 0.6572 - accuracy: 0.7495 - val_loss: 0.8351 - val_accuracy: 0.7200
# Epoch 73/100
# 499/499 [==============================] - 74s 149ms/sample - loss: 1.2539 - accuracy: 0.5812 - val_loss: 0.9288 - val_accuracy: 0.6480
# Epoch 74/100
# 499/499 [==============================] - 74s 148ms/sample - loss: 0.8483 - accuracy: 0.6613 - val_loss: 1.0272 - val_accuracy: 0.5920
# Epoch 75/100
# 499/499 [==============================] - 74s 149ms/sample - loss: 0.6084 - accuracy: 0.7515 - val_loss: 1.0468 - val_accuracy: 0.5600
# Epoch 76/100
# 499/499 [==============================] - 75s 150ms/sample - loss: 0.9813 - accuracy: 0.6253 - val_loss: 0.8645 - val_accuracy: 0.6000
# Epoch 77/100
# 499/499 [==============================] - 74s 148ms/sample - loss: 0.5551 - accuracy: 0.7756 - val_loss: 0.7739 - val_accuracy: 0.7040
# Epoch 78/100
# 499/499 [==============================] - 74s 149ms/sample - loss: 1.5059 - accuracy: 0.5551 - val_loss: 1.4705 - val_accuracy: 0.3760
# Epoch 79/100
# 499/499 [==============================] - 74s 149ms/sample - loss: 0.9657 - accuracy: 0.6733 - val_loss: 0.9871 - val_accuracy: 0.7360
# Epoch 80/100
# 499/499 [==============================] - 74s 149ms/sample - loss: 0.6564 - accuracy: 0.7936 - val_loss: 1.1923 - val_accuracy: 0.5440
# Epoch 81/100
# 499/499 [==============================] - 75s 150ms/sample - loss: 0.6727 - accuracy: 0.7756 - val_loss: 1.3134 - val_accuracy: 0.5280
# Epoch 82/100
# 499/499 [==============================] - 74s 149ms/sample - loss: 0.7705 - accuracy: 0.7034 - val_loss: 1.5578 - val_accuracy: 0.5920
# Epoch 83/100
# 499/499 [==============================] - 74s 149ms/sample - loss: 0.5426 - accuracy: 0.8036 - val_loss: 0.7400 - val_accuracy: 0.7120
# Epoch 84/100
# 499/499 [==============================] - 74s 149ms/sample - loss: 0.6148 - accuracy: 0.7575 - val_loss: 0.9989 - val_accuracy: 0.5680
# Epoch 85/100
# 499/499 [==============================] - 74s 148ms/sample - loss: 0.6328 - accuracy: 0.7615 - val_loss: 0.5597 - val_accuracy: 0.8560
# Epoch 86/100
# 499/499 [==============================] - 74s 149ms/sample - loss: 0.4414 - accuracy: 0.8357 - val_loss: 1.4163 - val_accuracy: 0.5120
# Epoch 87/100
# 499/499 [==============================] - 74s 149ms/sample - loss: 0.8607 - accuracy: 0.7154 - val_loss: 0.7662 - val_accuracy: 0.8000
# Epoch 88/100
# 499/499 [==============================] - 74s 149ms/sample - loss: 0.4743 - accuracy: 0.8497 - val_loss: 0.6836 - val_accuracy: 0.7360
# Epoch 89/100
# 499/499 [==============================] - 74s 149ms/sample - loss: 0.3778 - accuracy: 0.8637 - val_loss: 0.6027 - val_accuracy: 0.8160
# Epoch 90/100
# 499/499 [==============================] - 75s 150ms/sample - loss: 0.3888 - accuracy: 0.8557 - val_loss: 1.5995 - val_accuracy: 0.5440
# Epoch 91/100
# 499/499 [==============================] - 74s 149ms/sample - loss: 0.6142 - accuracy: 0.7876 - val_loss: 0.5978 - val_accuracy: 0.7600
# Epoch 92/100
# 499/499 [==============================] - 75s 149ms/sample - loss: 0.3602 - accuracy: 0.8677 - val_loss: 0.5937 - val_accuracy: 0.7360
# Epoch 93/100
# 499/499 [==============================] - 74s 149ms/sample - loss: 1.2075 - accuracy: 0.6433 - val_loss: 0.9696 - val_accuracy: 0.6720
# Epoch 94/100
# 499/499 [==============================] - 74s 148ms/sample - loss: 0.4802 - accuracy: 0.8357 - val_loss: 0.5823 - val_accuracy: 0.8240
# Epoch 95/100
# 499/499 [==============================] - 74s 149ms/sample - loss: 0.4279 - accuracy: 0.8497 - val_loss: 0.5898 - val_accuracy: 0.8080
# Epoch 96/100
# 499/499 [==============================] - 75s 150ms/sample - loss: 0.4101 - accuracy: 0.8337 - val_loss: 0.6661 - val_accuracy: 0.7440
# Epoch 97/100
# 499/499 [==============================] - 74s 149ms/sample - loss: 0.7104 - accuracy: 0.7876 - val_loss: 1.7754 - val_accuracy: 0.4000
# Epoch 98/100
# 499/499 [==============================] - 74s 149ms/sample - loss: 0.9236 - accuracy: 0.6373 - val_loss: 1.0439 - val_accuracy: 0.4960
# Epoch 99/100
# 499/499 [==============================] - 75s 149ms/sample - loss: 0.6101 - accuracy: 0.7695 - val_loss: 0.8186 - val_accuracy: 0.7280
# Epoch 100/100
# 499/499 [==============================] - 74s 148ms/sample - loss: 0.3518 - accuracy: 0.9038 - val_loss: 0.8693 - val_accuracy: 0.6800

# %%
cnn.evaluate(X_test_resize,y_test)
# Out:
# 125/125 [==============================] - 5s 40ms/sample - loss: 0.8693 - accuracy: 0.6800
# [0.8692868180274963, 0.68]

# %%
from sklearn.metrics import confusion_matrix , classification_report
import numpy as np
y_pred = cnn.predict(X_test_resize)
y_pred_classes = [np.argmax(element) for element in y_pred]

print("Classification Report: \n", classification_report(y_test, y_pred_classes))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.92      0.92        12
#            1       1.00      0.85      0.92        13
#            2       0.86      0.46      0.60        13
#            3       0.00      0.00      0.00        15
#            4       0.74      1.00      0.85        20
#            5       1.00      0.91      0.95        11
#            6       0.41      1.00      0.58         7
#            7       0.06      0.14      0.09         7
#            8       0.60      0.75      0.67        12
#            9       1.00      0.67      0.80        15
#
#     accuracy                           0.68       125
#    macro avg       0.66      0.67      0.64       125
# weighted avg       0.69      0.68      0.66       125
# c:\Users\omar_\anaconda3\envs\deeplearning\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\omar_\anaconda3\envs\deeplearning\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\omar_\anaconda3\envs\deeplearning\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
print('Percentage correct: ', 100*np.sum(y_pred_classes == y_test)/len(y_test))
# Out:
# Percentage correct:  68.0

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import pandas as pd

cmx=confusion_matrix(y_test, y_pred_classes, labels=labelsN)

df2 = pd.DataFrame(cmx, columns=labels, index=labels)
df2.columns.name = 'prediction'
df2.index.name = 'label'
df2
# Out:
# prediction                       Bifidobacterium spp(-ve)  \
# label
# Bifidobacterium spp(-ve)                               11
# Candida Albicans(-ve)                                   1
# Enterococcus faecalis(-ve)                              0
# Escherichia Coli(+ve)                                   0
# Fusobacterium(+ve)                                      0
# Lactobacillus Gasseri(-ve)                              0
# Listeria Monocytogenes(-ve)                             0
# Pseudomonas Aeruginosa(+ve)                             0
# Staphylococcus Epidermidis(-ve)                         0
# Streptococcus Agalactiae(-ve)                           0
#
# prediction                       Candida Albicans(-ve)  \
# label
# Bifidobacterium spp(-ve)                             0
# Candida Albicans(-ve)                               11
# Enterococcus faecalis(-ve)                           0
# Escherichia Coli(+ve)                                0
# Fusobacterium(+ve)                                   0
# Lactobacillus Gasseri(-ve)                           0
# Listeria Monocytogenes(-ve)                          0
# Pseudomonas Aeruginosa(+ve)                          0
# Staphylococcus Epidermidis(-ve)                      0
# Streptococcus Agalactiae(-ve)                        0
#
# prediction                       Enterococcus faecalis(-ve)  \
# label
# Bifidobacterium spp(-ve)                                  1
# Candida Albicans(-ve)                                     0
# Enterococcus faecalis(-ve)                                6
# Escherichia Coli(+ve)                                     0
# Fusobacterium(+ve)                                        0
# Lactobacillus Gasseri(-ve)                                0
# Listeria Monocytogenes(-ve)                               0
# Pseudomonas Aeruginosa(+ve)                               0
# Staphylococcus Epidermidis(-ve)                           0
# Streptococcus Agalactiae(-ve)                             0
#
# prediction                       Escherichia Coli(+ve)  Fusobacterium(+ve)  \
# label
# Bifidobacterium spp(-ve)                             0                   0
# Candida Albicans(-ve)                                0                   0
# Enterococcus faecalis(-ve)                           0                   0
# Escherichia Coli(+ve)                                0                   1
# Fusobacterium(+ve)                                   0                  20
# Lactobacillus Gasseri(-ve)                           0                   0
# Listeria Monocytogenes(-ve)                          0                   0
# Pseudomonas Aeruginosa(+ve)                          0                   6
# Staphylococcus Epidermidis(-ve)                      0                   0
# Streptococcus Agalactiae(-ve)                        0                   0
#
# prediction                       Lactobacillus Gasseri(-ve)  \
# label
# Bifidobacterium spp(-ve)                                  0
# Candida Albicans(-ve)                                     0
# Enterococcus faecalis(-ve)                                0
# Escherichia Coli(+ve)                                     0
# Fusobacterium(+ve)                                        0
# Lactobacillus Gasseri(-ve)                               10
# Listeria Monocytogenes(-ve)                               0
# Pseudomonas Aeruginosa(+ve)                               0
# Staphylococcus Epidermidis(-ve)                           0
# Streptococcus Agalactiae(-ve)                             0
#
# prediction                       Listeria Monocytogenes(-ve)  \
# label
# Bifidobacterium spp(-ve)                                   0
# Candida Albicans(-ve)                                      1
# Enterococcus faecalis(-ve)                                 3
# Escherichia Coli(+ve)                                      0
# Fusobacterium(+ve)                                         0
# Lactobacillus Gasseri(-ve)                                 0
# Listeria Monocytogenes(-ve)                                7
# Pseudomonas Aeruginosa(+ve)                                0
# Staphylococcus Epidermidis(-ve)                            3
# Streptococcus Agalactiae(-ve)                              3
#
# prediction                       Pseudomonas Aeruginosa(+ve)  \
# label
# Bifidobacterium spp(-ve)                                   0
# Candida Albicans(-ve)                                      0
# Enterococcus faecalis(-ve)                                 1
# Escherichia Coli(+ve)                                     14
# Fusobacterium(+ve)                                         0
# Lactobacillus Gasseri(-ve)                                 0
# Listeria Monocytogenes(-ve)                                0
# Pseudomonas Aeruginosa(+ve)                                1
# Staphylococcus Epidermidis(-ve)                            0
# Streptococcus Agalactiae(-ve)                              0
#
# prediction                       Staphylococcus Epidermidis(-ve)  \
# label
# Bifidobacterium spp(-ve)                                       0
# Candida Albicans(-ve)                                          0
# Enterococcus faecalis(-ve)                                     3
# Escherichia Coli(+ve)                                          0
# Fusobacterium(+ve)                                             0
# Lactobacillus Gasseri(-ve)                                     1
# Listeria Monocytogenes(-ve)                                    0
# Pseudomonas Aeruginosa(+ve)                                    0
# Staphylococcus Epidermidis(-ve)                                9
# Streptococcus Agalactiae(-ve)                                  2
#
# prediction                       Streptococcus Agalactiae(-ve)
# label
# Bifidobacterium spp(-ve)                                     0
# Candida Albicans(-ve)                                        0
# Enterococcus faecalis(-ve)                                   0
# Escherichia Coli(+ve)                                        0
# Fusobacterium(+ve)                                           0
# Lactobacillus Gasseri(-ve)                                   0
# Listeria Monocytogenes(-ve)                                  0
# Pseudomonas Aeruginosa(+ve)                                  0
# Staphylococcus Epidermidis(-ve)                              0
# Streptococcus Agalactiae(-ve)                               10

# %%
tp=0
fn=0
tn=0
fp=0

for i in range(len(labels)):
    for k in range(len(labels)):
        if k == i:
            tp+=cmx[i][k]
            if cmx[i][i]==0:
                fn+=1
        else:
            if cmx[i][k]!=0:
                fp+=cmx[i][k]
            else:
                tn+=1
                          

print('TP:', tp)
print('FP:', fp)
print('TN:', tn)
print('FN:', fn)

prec=(tp/(tp+fp))*100
recall=((tp)/(tp+fn))*100
acc=((tp+tn)/(tp+fp+tn+fn))*100
spec=((tn)/(tn+fp))*100
print('Precision:' + str(prec) +
     '\nRecall:' + str(recall) +
      '\nAccuracy:' + str(acc) +
      '\nSpecificity:' + str(spec))
# Out:
# TP: 85
# FP: 40
# TN: 77
# FN: 1
# Precision:68.0
# Recall:98.83720930232558
# Accuracy:79.80295566502463
# Specificity:65.8119658119658

# %%
n=np.random.randint(0, X_test.shape[0])
img = X_test_resize[n]
plt.imshow(img)
input_img = np.expand_dims(img, axis=0) #Expand dims so the input is (num images, x, y, c)
y_pred_rand = cnn.predict(input_img)[0]

y_pred_rand_class = np.argmax(y_pred_rand)
y_pred_rand_class=le.inverse_transform([y_pred_rand_class])
y_actual = le.inverse_transform([y_test[n]])

print("The prediction for this image is: ", y_pred_rand_class)
print("The actual label for this image is: ", y_actual)
# Out:
# The prediction for this image is:  ['Listeria Monocytogenes(-ve)']
# The actual label for this image is:  ['Staphylococcus Epidermidis(-ve)']
