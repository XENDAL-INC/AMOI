# %%
# %matplotlib inline

import tensorflow as tf
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.applications.vgg16 import VGG16
from sklearn import preprocessing
import matplotlib.pyplot as plt
import numpy as np
import os
import pprint
pp = pprint.PrettyPrinter(indent=4)

# %%
import joblib
from skimage.io import imread
from skimage.transform import resize

gramPositive_labels=['Escherichia Coli(+ve)',
 'Fusobacterium(+ve)',
 'Pseudomonas Aeruginosa(+ve)']
gramNegative_labels=['Bifidobacterium spp(-ve)',
 'Candida Albicans(-ve)',
 'Enterococcus faecalis(-ve)',
 'Lactobacillus Gasseri(-ve)',
 'Listeria Monocytogenes(-ve)',
 'Staphylococcus Epidermidis(-ve)',
 'Streptococcus Agalactiae(-ve)']

all_labels=['Bifidobacterium spp(-ve)',
 'Candida Albicans(-ve)',
 'Enterococcus faecalis(-ve)',
 'Escherichia Coli(+ve)',
 'Fusobacterium(+ve)',
 'Lactobacillus Gasseri(-ve)',
 'Listeria Monocytogenes(-ve)',
 'Pseudomonas Aeruginosa(+ve)',
 'Staphylococcus Epidermidis(-ve)',
 'Streptococcus Agalactiae(-ve)']

labels = all_labels

labelsN = []
i=0
for label in labels:
    labelsN.append(int(i))
    i=i+1

def resize_all(src, pklname, include, width=2048, height=1532):
    """
    load images from path, resize them and write them as arrays to a dictionary, 
    together with labels and metadata. The dictionary is written to a pickle file 
    named '{pklname}_{width}x{height}px.pkl'.
     
    Parameter
    ---------
    src: str
        path to data
    pklname: str
        path to output file
    width: int
        target width of the image in pixels
    include: set[str]
        set containing str
    """
     
    height = height if height is not None else width
     
    data = dict()
    data['description'] = 'bacteria images'.format(int(width), int(height))
    data['label'] = []
    data['filename'] = []
    data['data'] = []
     
    pklname = f"{pklname}_{width}x{height}px.pkl"
    
    # read all images in PATH, resize and write to DESTINATION_PATH
    for subdir in os.listdir(src):
        if subdir in include:
            print(subdir)
            current_path = os.path.join(src, subdir)
 
            for file in os.listdir(current_path):
                if file[-3:] in {'jpg', 'png'}:
                    im = imread(os.path.join(current_path, file))
                    #im = resize(im, (width, height)) #[:,:,::-1]
                    data['label'].append(subdir)
                    data['filename'].append(file)
                    data['data'].append(im)
                    imH = np.fliplr(im)
                    imV = np.flipud(im)
                    #flipH
                    data['label'].append(subdir)
                    data['filename'].append("flipH_" + file)
                    data['data'].append(imH)
                    #flipV
                    data['label'].append(subdir)
                    data['filename'].append("flipV_" + file)
                    data['data'].append(imV)

 
        joblib.dump(data, pklname)

# %%
# modify to fit your system
data_path = 'D:/Xendal/University/Grad/Dataset'
os.listdir(data_path)
# Out:
# ['Bifidobacterium spp(-ve)',
#  'Candida Albicans(-ve)',
#  'Enterococcus faecalis(-ve)',
#  'Escherichia Coli(+ve)',
#  'Fusobacterium(+ve)',
#  'Lactobacillus Gasseri(-ve)',
#  'Listeria Monocytogenes(-ve)',
#  'Pseudomonas Aeruginosa(+ve)',
#  'Staphylococcus Epidermidis(-ve)',
#  'Streptococcus Agalactiae(-ve)']

# %%
base_name = 'D:/Xendal/University/Grad/datasetPickle/augmented_bacteria'
width = 2048
height = 1532

gramPositive_include={'Escherichia Coli(+ve)',
 'Fusobacterium(+ve)',
 'Pseudomonas Aeruginosa(+ve)'}

gramNegative_include={'Bifidobacterium spp(-ve)',
 'Candida Albicans(-ve)',
 'Enterococcus faecalis(-ve)',
 'Lactobacillus Gasseri(-ve)',
 'Listeria Monocytogenes(-ve)',
 'Staphylococcus Epidermidis(-ve)',
 'Streptococcus Agalactiae(-ve)'}

all_include={'Bifidobacterium spp(-ve)',
 'Candida Albicans(-ve)',
 'Enterococcus faecalis(-ve)',
 'Escherichia Coli(+ve)',
 'Fusobacterium(+ve)',
 'Lactobacillus Gasseri(-ve)',
 'Listeria Monocytogenes(-ve)',
 'Pseudomonas Aeruginosa(+ve)',
 'Staphylococcus Epidermidis(-ve)',
 'Streptococcus Agalactiae(-ve)'}

include = all_include
   
#resize_all(src=data_path, pklname=base_name, width=width, include=include,)

# %%
from collections import Counter
 
data = joblib.load(f'{base_name}_{width}x{height}px.pkl')
 
print('number of samples: ', len(data['data']))
print('keys: ', list(data.keys()))
print('description: ', data['description'])
print('image shape: ', data['data'][0].shape)
print('labels:', np.unique(data['label']))
 
Counter(data['label'])
# Out:
# number of samples:  624
# keys:  ['description', 'label', 'filename', 'data']
# description:  bacteria images
# image shape:  (1532, 2048, 3)
# labels: ['Bifidobacterium spp(-ve)' 'Candida Albicans(-ve)'
#  'Enterococcus faecalis(-ve)' 'Escherichia Coli(+ve)' 'Fusobacterium(+ve)'
#  'Lactobacillus Gasseri(-ve)' 'Listeria Monocytogenes(-ve)'
#  'Pseudomonas Aeruginosa(+ve)' 'Staphylococcus Epidermidis(-ve)'
#  'Streptococcus Agalactiae(-ve)']
# Counter({'Bifidobacterium spp(-ve)': 69,
#          'Candida Albicans(-ve)': 60,
#          'Enterococcus faecalis(-ve)': 60,
#          'Escherichia Coli(+ve)': 60,
#          'Fusobacterium(+ve)': 69,
#          'Lactobacillus Gasseri(-ve)': 60,
#          'Listeria Monocytogenes(-ve)': 66,
#          'Pseudomonas Aeruginosa(+ve)': 60,
#          'Staphylococcus Epidermidis(-ve)': 60,
#          'Streptococcus Agalactiae(-ve)': 60})

# %%
# use np.unique to get all unique values in the list of labels
labels = np.unique(data['label'])
 
# set up the matplotlib figure and axes, based on the number of labels
fig, axes = plt.subplots(1, len(labels))
fig.set_size_inches(15,4)
fig.tight_layout()
 
# make a plot for every label (equipment) type. The index method returns the 
# index of the first item corresponding to its search string, label in this case
for ax, label in zip(axes, labels):
    idx = data['label'].index(label)
     
    ax.imshow(data['data'][idx])
    ax.axis('off')
    ax.set_title(label)

# %%
X = np.array(data['data'])
y = np.array(data['label'])

# %%
le = preprocessing.LabelEncoder()
le.fit(y)
y_labels_encoded = le.transform(y)

# %%
from sklearn.model_selection import train_test_split
 
X_train, X_test, y_train, y_test = train_test_split(
    X, 
    y_labels_encoded, 
    test_size=0.2, 
    shuffle=True,
    random_state=42,
)

# %%
def plot_bar(y, loc='left', relative=True):
    width = 0.35
    if loc == 'left':
        n = -0.5
    elif loc == 'right':
        n = 0.5
     
    # calculate counts per type and sort, to ensure their order
    unique, counts = np.unique(y, return_counts=True)
    sorted_index = np.argsort(unique)
    unique = unique[sorted_index]
     
    if relative:
        # plot as a percentage
        counts = 100*counts[sorted_index]/len(y)
        ylabel_text = '% count'
    else:
        # plot counts
        counts = counts[sorted_index]
        ylabel_text = 'count'
         
    xtemp = np.arange(len(unique))
     
    plt.bar(xtemp + n*width, counts, align='center', alpha=.7, width=width)
    plt.xticks(xtemp, unique, rotation=45)
    plt.xlabel('equipment type')
    plt.ylabel(ylabel_text)
    
plt.suptitle('relative amount of photos per type')
plot_bar(y_train, loc='left')
plot_bar(y_test, loc='right')
plt.legend([
    'train ({0} photos)'.format(len(y_train)), 
    'test ({0} photos)'.format(len(y_test))
]);

# %%
from sklearn.base import BaseEstimator, TransformerMixin
from skimage import color
from skimage.feature import hog
from sklearn import svm
from sklearn.metrics import classification_report,accuracy_score

# %%
class ResizeTransformer(BaseEstimator, TransformerMixin):
    """
    Scales array to 1/3
    """
 
    def __init__(self):
        pass
 
    def fit(self, X, y=None):
        """returns itself"""
        return self
 
    def transform(self, X, y=None):
        """perform the transformation and return an array"""
        return np.array([resize(img, (img.shape[0] // 6.8, img.shape[1] // 6.8), anti_aliasing='True') for img in X])

# %%
from sklearn.linear_model import SGDClassifier
from sklearn.model_selection import cross_val_predict
from sklearn.preprocessing import StandardScaler, Normalizer
import skimage
import cv2 as cv
from skimage.transform import rescale

resizify = ResizeTransformer()

X_train_resize=resizify.fit_transform(X_train)

print(X_train.shape)
print(X_train_resize.shape)
# Out:
# (499, 1532, 2048, 3)
# (499, 225, 301, 3)

# %%
X_test_resize=resizify.fit_transform(X_test)

print(X_test.shape)
print(X_test_resize.shape)
# Out:
# (125, 1532, 2048, 3)
# (125, 225, 301, 3)

# %%
tf.keras.backend.clear_session()
cnn = models.Sequential()
cnn.add(layers.Conv2D(32, (3,3), activation='relu', input_shape=(225,301,3)))
cnn.add(layers.MaxPooling2D((2,2)))

cnn.add(layers.Conv2D(64, (3,3), activation='relu'))
cnn.add(layers.MaxPooling2D((2,2)))

cnn.add(layers.Conv2D(64, (3,3), activation='relu'))
cnn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 223, 299, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 111, 149, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 109, 147, 64)      18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 54, 73, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 52, 71, 64)        36928
# =================================================================
# Total params: 56,320
# Trainable params: 56,320
# Non-trainable params: 0
# _________________________________________________________________

# %%
cnn.add(layers.Flatten())
cnn.add(layers.Dense(64, activation='relu'))
cnn.add(layers.Dense(10, activation='softmax'))
cnn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 223, 299, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 111, 149, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 109, 147, 64)      18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 54, 73, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 52, 71, 64)        36928
# _________________________________________________________________
# flatten (Flatten)            (None, 236288)            0
# _________________________________________________________________
# dense (Dense)                (None, 64)                15122496
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                650
# =================================================================
# Total params: 15,179,466
# Trainable params: 15,179,466
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import SGD,Adam
opt = SGD(lr=0.01)
cnn.compile(optimizer=opt,
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history = cnn.fit(X_train_resize, y_train, epochs=100, steps_per_epoch=len(X_train_resize)/32, validation_data=(X_test_resize, y_test), batch_size=32)
# Out:
# Train on 499 samples, validate on 125 samples
# Epoch 1/100
# 499/499 [==============================] - 26s 52ms/sample - loss: 2.3079 - accuracy: 0.0942 - val_loss: 2.3023 - val_accuracy: 0.0560
# Epoch 2/100
# 499/499 [==============================] - 23s 47ms/sample - loss: 2.3015 - accuracy: 0.1082 - val_loss: 2.3110 - val_accuracy: 0.0560
# Epoch 3/100
# 499/499 [==============================] - 24s 48ms/sample - loss: 2.2978 - accuracy: 0.1042 - val_loss: 2.3152 - val_accuracy: 0.0560
# Epoch 4/100
# 499/499 [==============================] - 24s 47ms/sample - loss: 2.2976 - accuracy: 0.1002 - val_loss: 2.3033 - val_accuracy: 0.0640
# Epoch 5/100
# 499/499 [==============================] - 23s 45ms/sample - loss: 2.2888 - accuracy: 0.0782 - val_loss: 2.2860 - val_accuracy: 0.0800
# Epoch 6/100
# 499/499 [==============================] - 23s 47ms/sample - loss: 2.2711 - accuracy: 0.1503 - val_loss: 2.3108 - val_accuracy: 0.1280
# Epoch 7/100
# 499/499 [==============================] - 24s 47ms/sample - loss: 2.2699 - accuracy: 0.1443 - val_loss: 2.3180 - val_accuracy: 0.0880
# Epoch 8/100
# 499/499 [==============================] - 23s 46ms/sample - loss: 2.2675 - accuracy: 0.1764 - val_loss: 2.2514 - val_accuracy: 0.1440
# Epoch 9/100
# 499/499 [==============================] - 22s 45ms/sample - loss: 2.2439 - accuracy: 0.1603 - val_loss: 2.2597 - val_accuracy: 0.1440
# Epoch 10/100
# 499/499 [==============================] - 22s 45ms/sample - loss: 2.2382 - accuracy: 0.1804 - val_loss: 2.2782 - val_accuracy: 0.1600
# Epoch 11/100
# 499/499 [==============================] - 22s 45ms/sample - loss: 2.2370 - accuracy: 0.1583 - val_loss: 2.2657 - val_accuracy: 0.1840
# Epoch 12/100
# 499/499 [==============================] - 24s 48ms/sample - loss: 2.1442 - accuracy: 0.2305 - val_loss: 2.1084 - val_accuracy: 0.1840
# Epoch 13/100
# 499/499 [==============================] - 23s 46ms/sample - loss: 2.3188 - accuracy: 0.1263 - val_loss: 2.2919 - val_accuracy: 0.1360
# Epoch 14/100
# 499/499 [==============================] - 24s 48ms/sample - loss: 2.2839 - accuracy: 0.1383 - val_loss: 2.3118 - val_accuracy: 0.0880
# Epoch 15/100
# 499/499 [==============================] - 24s 49ms/sample - loss: 2.2745 - accuracy: 0.1102 - val_loss: 2.3713 - val_accuracy: 0.0880
# Epoch 16/100
# 499/499 [==============================] - 23s 45ms/sample - loss: 2.2599 - accuracy: 0.1643 - val_loss: 2.2846 - val_accuracy: 0.0880
# Epoch 17/100
# 499/499 [==============================] - 24s 48ms/sample - loss: 2.2311 - accuracy: 0.1824 - val_loss: 2.2432 - val_accuracy: 0.1040
# Epoch 18/100
# 499/499 [==============================] - 22s 45ms/sample - loss: 2.2323 - accuracy: 0.1563 - val_loss: 2.2331 - val_accuracy: 0.0960
# Epoch 19/100
# 499/499 [==============================] - 22s 45ms/sample - loss: 2.2232 - accuracy: 0.1904 - val_loss: 2.2213 - val_accuracy: 0.0960
# Epoch 20/100
# 499/499 [==============================] - 23s 47ms/sample - loss: 2.2310 - accuracy: 0.1663 - val_loss: 2.2324 - val_accuracy: 0.1120
# Epoch 21/100
# 499/499 [==============================] - 23s 46ms/sample - loss: 2.2474 - accuracy: 0.1463 - val_loss: 2.3098 - val_accuracy: 0.0560
# Epoch 22/100
# 499/499 [==============================] - 23s 46ms/sample - loss: 2.1949 - accuracy: 0.1824 - val_loss: 2.3009 - val_accuracy: 0.0640
# Epoch 23/100
# 499/499 [==============================] - 23s 46ms/sample - loss: 2.2139 - accuracy: 0.1884 - val_loss: 2.1617 - val_accuracy: 0.1440
# Epoch 24/100
# 499/499 [==============================] - 24s 48ms/sample - loss: 2.1365 - accuracy: 0.2204 - val_loss: 2.1184 - val_accuracy: 0.1920
# Epoch 25/100
# 499/499 [==============================] - 24s 48ms/sample - loss: 2.2274 - accuracy: 0.2004 - val_loss: 2.2416 - val_accuracy: 0.1600
# Epoch 26/100
# 499/499 [==============================] - 22s 44ms/sample - loss: 2.1179 - accuracy: 0.2224 - val_loss: 2.8101 - val_accuracy: 0.0560
# Epoch 27/100
# 499/499 [==============================] - 23s 46ms/sample - loss: 2.2418 - accuracy: 0.1603 - val_loss: 2.1934 - val_accuracy: 0.0560
# Epoch 28/100
# 499/499 [==============================] - 23s 46ms/sample - loss: 2.2595 - accuracy: 0.1703 - val_loss: 2.2708 - val_accuracy: 0.1920
# Epoch 29/100
# 499/499 [==============================] - 25s 49ms/sample - loss: 2.2792 - accuracy: 0.1082 - val_loss: 2.3229 - val_accuracy: 0.0880
# Epoch 30/100
# 499/499 [==============================] - 23s 45ms/sample - loss: 2.2539 - accuracy: 0.1643 - val_loss: 2.2613 - val_accuracy: 0.2000
# Epoch 31/100
# 499/499 [==============================] - 23s 45ms/sample - loss: 2.0915 - accuracy: 0.2405 - val_loss: 2.1748 - val_accuracy: 0.0880
# Epoch 32/100
# 499/499 [==============================] - 23s 45ms/sample - loss: 2.1711 - accuracy: 0.2064 - val_loss: 2.1844 - val_accuracy: 0.2080
# Epoch 33/100
# 499/499 [==============================] - 22s 45ms/sample - loss: 2.0901 - accuracy: 0.2625 - val_loss: 1.9704 - val_accuracy: 0.3760
# Epoch 34/100
# 499/499 [==============================] - 22s 44ms/sample - loss: 2.2483 - accuracy: 0.2024 - val_loss: 2.1835 - val_accuracy: 0.1600
# Epoch 35/100
# 499/499 [==============================] - 23s 46ms/sample - loss: 2.0017 - accuracy: 0.3066 - val_loss: 2.3506 - val_accuracy: 0.0560
# Epoch 36/100
# 499/499 [==============================] - 23s 46ms/sample - loss: 2.1530 - accuracy: 0.2685 - val_loss: 1.9909 - val_accuracy: 0.1920
# Epoch 37/100
# 499/499 [==============================] - 23s 46ms/sample - loss: 2.2617 - accuracy: 0.2786 - val_loss: 2.1397 - val_accuracy: 0.2000
# Epoch 38/100
# 499/499 [==============================] - 25s 51ms/sample - loss: 1.9915 - accuracy: 0.2786 - val_loss: 1.9411 - val_accuracy: 0.3520
# Epoch 39/100
# 499/499 [==============================] - 22s 45ms/sample - loss: 1.8621 - accuracy: 0.3327 - val_loss: 4.0046 - val_accuracy: 0.0880
# Epoch 40/100
# 499/499 [==============================] - 23s 45ms/sample - loss: 2.4103 - accuracy: 0.1182 - val_loss: 2.2741 - val_accuracy: 0.2240
# Epoch 41/100
# 499/499 [==============================] - 22s 45ms/sample - loss: 2.2707 - accuracy: 0.1403 - val_loss: 2.2486 - val_accuracy: 0.1120
# Epoch 42/100
# 499/499 [==============================] - 23s 45ms/sample - loss: 2.2838 - accuracy: 0.1844 - val_loss: 2.2577 - val_accuracy: 0.0960
# Epoch 43/100
# 499/499 [==============================] - 25s 49ms/sample - loss: 2.2737 - accuracy: 0.1563 - val_loss: 2.2283 - val_accuracy: 0.2640
# Epoch 44/100
# 499/499 [==============================] - 22s 45ms/sample - loss: 2.1944 - accuracy: 0.2044 - val_loss: 2.2699 - val_accuracy: 0.1040
# Epoch 45/100
# 499/499 [==============================] - 23s 45ms/sample - loss: 2.2054 - accuracy: 0.2285 - val_loss: 2.4695 - val_accuracy: 0.1040
# Epoch 46/100
# 499/499 [==============================] - 22s 45ms/sample - loss: 2.0758 - accuracy: 0.2806 - val_loss: 2.0714 - val_accuracy: 0.1760
# Epoch 47/100
# 499/499 [==============================] - 25s 50ms/sample - loss: 1.9577 - accuracy: 0.3106 - val_loss: 1.9366 - val_accuracy: 0.2400
# Epoch 48/100
# 499/499 [==============================] - 22s 45ms/sample - loss: 1.7706 - accuracy: 0.3928 - val_loss: 2.0716 - val_accuracy: 0.1600
# Epoch 49/100
# 499/499 [==============================] - 23s 46ms/sample - loss: 1.7422 - accuracy: 0.3567 - val_loss: 2.6512 - val_accuracy: 0.1600
# Epoch 50/100
# 499/499 [==============================] - 22s 44ms/sample - loss: 1.7640 - accuracy: 0.4008 - val_loss: 1.7664 - val_accuracy: 0.4800
# Epoch 51/100
# 499/499 [==============================] - 23s 46ms/sample - loss: 2.1097 - accuracy: 0.3567 - val_loss: 2.0951 - val_accuracy: 0.2240
# Epoch 52/100
# 499/499 [==============================] - 24s 48ms/sample - loss: 1.8299 - accuracy: 0.3527 - val_loss: 1.8082 - val_accuracy: 0.3760
# Epoch 53/100
# 499/499 [==============================] - 22s 45ms/sample - loss: 1.6244 - accuracy: 0.4489 - val_loss: 1.7636 - val_accuracy: 0.2880
# Epoch 54/100
# 499/499 [==============================] - 25s 50ms/sample - loss: 1.5999 - accuracy: 0.4068 - val_loss: 1.8919 - val_accuracy: 0.3840
# Epoch 55/100
# 499/499 [==============================] - 22s 45ms/sample - loss: 1.5479 - accuracy: 0.4950 - val_loss: 2.2041 - val_accuracy: 0.2960
# Epoch 56/100
# 499/499 [==============================] - 24s 47ms/sample - loss: 1.6294 - accuracy: 0.4168 - val_loss: 1.8810 - val_accuracy: 0.2960
# Epoch 57/100
# 499/499 [==============================] - 23s 45ms/sample - loss: 1.6123 - accuracy: 0.4309 - val_loss: 2.0452 - val_accuracy: 0.2800
# Epoch 58/100
# 499/499 [==============================] - 22s 44ms/sample - loss: 1.3839 - accuracy: 0.5150 - val_loss: 1.7170 - val_accuracy: 0.2800
# Epoch 59/100
# 499/499 [==============================] - 25s 50ms/sample - loss: 1.3217 - accuracy: 0.5010 - val_loss: 2.3915 - val_accuracy: 0.1840
# Epoch 60/100
# 499/499 [==============================] - 23s 47ms/sample - loss: 1.4809 - accuracy: 0.4950 - val_loss: 1.9011 - val_accuracy: 0.3280
# Epoch 61/100
# 499/499 [==============================] - 23s 46ms/sample - loss: 1.1262 - accuracy: 0.6092 - val_loss: 2.1322 - val_accuracy: 0.2720
# Epoch 62/100
# 499/499 [==============================] - 22s 45ms/sample - loss: 1.6060 - accuracy: 0.5090 - val_loss: 1.9948 - val_accuracy: 0.2160
# Epoch 63/100
# 499/499 [==============================] - 23s 46ms/sample - loss: 1.1660 - accuracy: 0.5852 - val_loss: 1.7898 - val_accuracy: 0.2720
# Epoch 64/100
# 499/499 [==============================] - 23s 46ms/sample - loss: 1.1689 - accuracy: 0.6052 - val_loss: 1.9752 - val_accuracy: 0.3280
# Epoch 65/100
# 499/499 [==============================] - 23s 45ms/sample - loss: 1.1080 - accuracy: 0.6172 - val_loss: 1.7189 - val_accuracy: 0.3200
# Epoch 66/100
# 499/499 [==============================] - 23s 45ms/sample - loss: 1.1397 - accuracy: 0.6012 - val_loss: 1.6807 - val_accuracy: 0.3280
# Epoch 67/100
# 499/499 [==============================] - 23s 46ms/sample - loss: 0.8398 - accuracy: 0.7355 - val_loss: 1.4555 - val_accuracy: 0.4400
# Epoch 68/100
# 499/499 [==============================] - 25s 49ms/sample - loss: 1.1092 - accuracy: 0.6192 - val_loss: 1.6579 - val_accuracy: 0.4400
# Epoch 69/100
# 499/499 [==============================] - 24s 47ms/sample - loss: 0.9589 - accuracy: 0.6333 - val_loss: 1.6360 - val_accuracy: 0.4720
# Epoch 70/100
# 499/499 [==============================] - 23s 45ms/sample - loss: 0.7248 - accuracy: 0.7375 - val_loss: 1.7076 - val_accuracy: 0.3120
# Epoch 71/100
# 499/499 [==============================] - 22s 45ms/sample - loss: 1.0283 - accuracy: 0.6713 - val_loss: 1.8208 - val_accuracy: 0.3440
# Epoch 72/100
# 499/499 [==============================] - 23s 46ms/sample - loss: 1.1633 - accuracy: 0.6293 - val_loss: 2.3578 - val_accuracy: 0.1040
# Epoch 73/100
# 499/499 [==============================] - 23s 46ms/sample - loss: 1.4980 - accuracy: 0.4950 - val_loss: 2.1582 - val_accuracy: 0.1680
# Epoch 74/100
# 499/499 [==============================] - 24s 48ms/sample - loss: 1.1109 - accuracy: 0.6293 - val_loss: 1.7735 - val_accuracy: 0.3840
# Epoch 75/100
# 499/499 [==============================] - 23s 46ms/sample - loss: 0.8037 - accuracy: 0.7014 - val_loss: 1.9127 - val_accuracy: 0.3360
# Epoch 76/100
# 499/499 [==============================] - 23s 46ms/sample - loss: 0.6225 - accuracy: 0.7776 - val_loss: 1.8620 - val_accuracy: 0.4480
# Epoch 77/100
# 499/499 [==============================] - 23s 47ms/sample - loss: 0.6723 - accuracy: 0.7776 - val_loss: 1.9870 - val_accuracy: 0.4800
# Epoch 78/100
# 499/499 [==============================] - 22s 45ms/sample - loss: 1.0528 - accuracy: 0.6653 - val_loss: 1.9449 - val_accuracy: 0.3360
# Epoch 79/100
# 499/499 [==============================] - 25s 50ms/sample - loss: 0.5871 - accuracy: 0.7756 - val_loss: 1.6807 - val_accuracy: 0.4640
# Epoch 80/100
# 499/499 [==============================] - 22s 44ms/sample - loss: 0.4932 - accuracy: 0.8016 - val_loss: 1.7189 - val_accuracy: 0.3600
# Epoch 81/100
# 499/499 [==============================] - 23s 47ms/sample - loss: 0.4540 - accuracy: 0.8076 - val_loss: 1.6384 - val_accuracy: 0.4720
# Epoch 82/100
# 499/499 [==============================] - 22s 45ms/sample - loss: 0.4091 - accuracy: 0.8557 - val_loss: 1.6657 - val_accuracy: 0.3840
# Epoch 83/100
# 499/499 [==============================] - 22s 45ms/sample - loss: 0.5475 - accuracy: 0.7896 - val_loss: 2.2038 - val_accuracy: 0.3040
# Epoch 84/100
# 499/499 [==============================] - 22s 44ms/sample - loss: 0.5476 - accuracy: 0.7595 - val_loss: 1.8683 - val_accuracy: 0.4320
# Epoch 85/100
# 499/499 [==============================] - 22s 43ms/sample - loss: 0.5845 - accuracy: 0.7916 - val_loss: 1.9111 - val_accuracy: 0.4400
# Epoch 86/100
# 499/499 [==============================] - 25s 51ms/sample - loss: 0.4392 - accuracy: 0.8236 - val_loss: 1.9502 - val_accuracy: 0.3680
# Epoch 87/100
# 499/499 [==============================] - 24s 47ms/sample - loss: 0.4226 - accuracy: 0.8337 - val_loss: 1.9178 - val_accuracy: 0.3120
# Epoch 88/100
# 499/499 [==============================] - 22s 45ms/sample - loss: 0.5253 - accuracy: 0.8216 - val_loss: 2.0531 - val_accuracy: 0.3200
# Epoch 89/100
# 499/499 [==============================] - 23s 47ms/sample - loss: 0.6230 - accuracy: 0.7555 - val_loss: 2.6467 - val_accuracy: 0.2720
# Epoch 90/100
# 499/499 [==============================] - 22s 44ms/sample - loss: 0.5219 - accuracy: 0.7836 - val_loss: 2.0583 - val_accuracy: 0.3600
# Epoch 91/100
# 499/499 [==============================] - 22s 44ms/sample - loss: 0.3194 - accuracy: 0.8798 - val_loss: 1.9212 - val_accuracy: 0.5600
# Epoch 92/100
# 499/499 [==============================] - 22s 44ms/sample - loss: 0.2865 - accuracy: 0.8998 - val_loss: 2.0828 - val_accuracy: 0.4480
# Epoch 93/100
# 499/499 [==============================] - 27s 53ms/sample - loss: 0.2662 - accuracy: 0.9299 - val_loss: 1.9716 - val_accuracy: 0.4720
# Epoch 94/100
# 499/499 [==============================] - 22s 44ms/sample - loss: 0.3097 - accuracy: 0.8577 - val_loss: 1.8446 - val_accuracy: 0.5920
# Epoch 95/100
# 499/499 [==============================] - 23s 46ms/sample - loss: 0.3131 - accuracy: 0.8717 - val_loss: 1.8128 - val_accuracy: 0.6000
# Epoch 96/100
# 499/499 [==============================] - 23s 45ms/sample - loss: 0.2487 - accuracy: 0.9138 - val_loss: 1.9349 - val_accuracy: 0.4960
# Epoch 97/100
# 499/499 [==============================] - 22s 45ms/sample - loss: 0.9719 - accuracy: 0.7355 - val_loss: 2.1133 - val_accuracy: 0.2880
# Epoch 98/100
# 499/499 [==============================] - 22s 45ms/sample - loss: 0.4938 - accuracy: 0.7896 - val_loss: 1.9499 - val_accuracy: 0.4800
# Epoch 99/100
# 499/499 [==============================] - 22s 45ms/sample - loss: 0.3037 - accuracy: 0.8938 - val_loss: 1.9536 - val_accuracy: 0.4640
# Epoch 100/100
# 499/499 [==============================] - 23s 46ms/sample - loss: 0.2612 - accuracy: 0.8938 - val_loss: 1.7874 - val_accuracy: 0.5680

# %%
cnn.evaluate(X_test_resize,y_test)
# Out:
# 125/125 [==============================] - 1s 11ms/sample - loss: 1.7874 - accuracy: 0.5680
# [1.7874413652420045, 0.568]

# %%
from sklearn.metrics import confusion_matrix , classification_report
import numpy as np
y_pred = cnn.predict(X_test_resize)
y_pred_classes = [np.argmax(element) for element in y_pred]

print("Classification Report: \n", classification_report(y_test, y_pred_classes))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.44      0.67      0.53        12
#            1       0.62      0.38      0.48        13
#            2       0.33      0.15      0.21        13
#            3       0.85      0.73      0.79        15
#            4       0.69      0.90      0.78        20
#            5       0.83      0.91      0.87        11
#            6       0.36      0.71      0.48         7
#            7       0.29      0.29      0.29         7
#            8       0.33      0.25      0.29        12
#            9       0.58      0.47      0.52        15
#
#     accuracy                           0.57       125
#    macro avg       0.53      0.55      0.52       125
# weighted avg       0.57      0.57      0.55       125

# %%
print('Percentage correct: ', 100*np.sum(y_pred_classes == y_test)/len(y_test))
# Out:
# Percentage correct:  56.8

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import pandas as pd

cmx=confusion_matrix(y_test, y_pred_classes, labels=labelsN)

df2 = pd.DataFrame(cmx, columns=labels, index=labels)
df2.columns.name = 'prediction'
df2.index.name = 'label'
df2
# Out:
# prediction                       Bifidobacterium spp(-ve)  \
# label
# Bifidobacterium spp(-ve)                                8
# Candida Albicans(-ve)                                   4
# Enterococcus faecalis(-ve)                              2
# Escherichia Coli(+ve)                                   0
# Fusobacterium(+ve)                                      0
# Lactobacillus Gasseri(-ve)                              1
# Listeria Monocytogenes(-ve)                             2
# Pseudomonas Aeruginosa(+ve)                             0
# Staphylococcus Epidermidis(-ve)                         0
# Streptococcus Agalactiae(-ve)                           1
#
# prediction                       Candida Albicans(-ve)  \
# label
# Bifidobacterium spp(-ve)                             2
# Candida Albicans(-ve)                                5
# Enterococcus faecalis(-ve)                           0
# Escherichia Coli(+ve)                                0
# Fusobacterium(+ve)                                   0
# Lactobacillus Gasseri(-ve)                           0
# Listeria Monocytogenes(-ve)                          0
# Pseudomonas Aeruginosa(+ve)                          0
# Staphylococcus Epidermidis(-ve)                      1
# Streptococcus Agalactiae(-ve)                        0
#
# prediction                       Enterococcus faecalis(-ve)  \
# label
# Bifidobacterium spp(-ve)                                  0
# Candida Albicans(-ve)                                     2
# Enterococcus faecalis(-ve)                                2
# Escherichia Coli(+ve)                                     0
# Fusobacterium(+ve)                                        0
# Lactobacillus Gasseri(-ve)                                0
# Listeria Monocytogenes(-ve)                               0
# Pseudomonas Aeruginosa(+ve)                               0
# Staphylococcus Epidermidis(-ve)                           2
# Streptococcus Agalactiae(-ve)                             0
#
# prediction                       Escherichia Coli(+ve)  Fusobacterium(+ve)  \
# label
# Bifidobacterium spp(-ve)                             0                   0
# Candida Albicans(-ve)                                0                   0
# Enterococcus faecalis(-ve)                           1                   1
# Escherichia Coli(+ve)                               11                   0
# Fusobacterium(+ve)                                   1                  18
# Lactobacillus Gasseri(-ve)                           0                   0
# Listeria Monocytogenes(-ve)                          0                   0
# Pseudomonas Aeruginosa(+ve)                          0                   5
# Staphylococcus Epidermidis(-ve)                      0                   2
# Streptococcus Agalactiae(-ve)                        0                   0
#
# prediction                       Lactobacillus Gasseri(-ve)  \
# label
# Bifidobacterium spp(-ve)                                  2
# Candida Albicans(-ve)                                     0
# Enterococcus faecalis(-ve)                                0
# Escherichia Coli(+ve)                                     0
# Fusobacterium(+ve)                                        0
# Lactobacillus Gasseri(-ve)                               10
# Listeria Monocytogenes(-ve)                               0
# Pseudomonas Aeruginosa(+ve)                               0
# Staphylococcus Epidermidis(-ve)                           0
# Streptococcus Agalactiae(-ve)                             0
#
# prediction                       Listeria Monocytogenes(-ve)  \
# label
# Bifidobacterium spp(-ve)                                   0
# Candida Albicans(-ve)                                      1
# Enterococcus faecalis(-ve)                                 2
# Escherichia Coli(+ve)                                      0
# Fusobacterium(+ve)                                         0
# Lactobacillus Gasseri(-ve)                                 0
# Listeria Monocytogenes(-ve)                                5
# Pseudomonas Aeruginosa(+ve)                                0
# Staphylococcus Epidermidis(-ve)                            2
# Streptococcus Agalactiae(-ve)                              4
#
# prediction                       Pseudomonas Aeruginosa(+ve)  \
# label
# Bifidobacterium spp(-ve)                                   0
# Candida Albicans(-ve)                                      0
# Enterococcus faecalis(-ve)                                 0
# Escherichia Coli(+ve)                                      4
# Fusobacterium(+ve)                                         1
# Lactobacillus Gasseri(-ve)                                 0
# Listeria Monocytogenes(-ve)                                0
# Pseudomonas Aeruginosa(+ve)                                2
# Staphylococcus Epidermidis(-ve)                            0
# Streptococcus Agalactiae(-ve)                              0
#
# prediction                       Staphylococcus Epidermidis(-ve)  \
# label
# Bifidobacterium spp(-ve)                                       0
# Candida Albicans(-ve)                                          1
# Enterococcus faecalis(-ve)                                     2
# Escherichia Coli(+ve)                                          0
# Fusobacterium(+ve)                                             0
# Lactobacillus Gasseri(-ve)                                     0
# Listeria Monocytogenes(-ve)                                    0
# Pseudomonas Aeruginosa(+ve)                                    0
# Staphylococcus Epidermidis(-ve)                                3
# Streptococcus Agalactiae(-ve)                                  3
#
# prediction                       Streptococcus Agalactiae(-ve)
# label
# Bifidobacterium spp(-ve)                                     0
# Candida Albicans(-ve)                                        0
# Enterococcus faecalis(-ve)                                   3
# Escherichia Coli(+ve)                                        0
# Fusobacterium(+ve)                                           0
# Lactobacillus Gasseri(-ve)                                   0
# Listeria Monocytogenes(-ve)                                  0
# Pseudomonas Aeruginosa(+ve)                                  0
# Staphylococcus Epidermidis(-ve)                              2
# Streptococcus Agalactiae(-ve)                                7

# %%
tp=0
fn=0
tn=0
fp=0

for i in range(len(labels)):
    for k in range(len(labels)):
        if k == i:
            tp+=cmx[i][k]
            if cmx[i][i]==0:
                fn+=1
        else:
            if cmx[i][k]!=0:
                fp+=cmx[i][k]
            else:
                tn+=1
                          

print('TP:', tp)
print('FP:', fp)
print('TN:', tn)
print('FN:', fn)

prec=(tp/(tp+fp))*100
recall=((tp)/(tp+fn))*100
acc=((tp+tn)/(tp+fp+tn+fn))*100
spec=((tn)/(tn+fp))*100
print('Precision:' + str(prec) +
     '\nRecall:' + str(recall) +
      '\nAccuracy:' + str(acc) +
      '\nSpecificity:' + str(spec))
# Out:
# TP: 71
# FP: 54
# TN: 64
# FN: 0
# Precision:56.8
# Recall:100.0
# Accuracy:71.42857142857143
# Specificity:54.23728813559322

# %%
n=np.random.randint(0, X_test.shape[0])
img = X_test_resize[n]
plt.imshow(img)
input_img = np.expand_dims(img, axis=0) #Expand dims so the input is (num images, x, y, c)
y_pred_rand = cnn.predict(input_img)[0]

y_pred_rand_class = np.argmax(y_pred_rand)
y_pred_rand_class=le.inverse_transform([y_pred_rand_class])
y_actual = le.inverse_transform([y_test[n]])

print("The prediction for this image is: ", y_pred_rand_class)
print("The actual label for this image is: ", y_actual)
# Out:
# The prediction for this image is:  ['Fusobacterium(+ve)']
# The actual label for this image is:  ['Fusobacterium(+ve)']
